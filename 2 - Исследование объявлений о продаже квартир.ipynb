# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера</h2>
#
# Привет! Меня зовут Алексей Тюрин, я буду делать ревью этой работы. Давай будем общаться на «ты».
#
# У тебя очень хорошая, детальная и вдумчивая работа, спасибо 👍 Поэтому я её с радостью приму :) Основной момент, на который можешь обратить внимание -- то, как много есть распределений и что какое описывает, ещё не стоит всё заменять на медианы, т.к. это потом влияет на расчёт корреляции.
#
#
# Зелёным цветом отмечены комментарии, не требующие правки. Жёлтым цветом выделено то, что в следующий раз можно сделать по-другому или можно поправить прямо сейчас.
#
# Давай работать над проектом в диалоге: если ты **что-то меняешь** в проекте по моим рекомендациям — **пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее». Если оставляешь комментарии на какой-то итерации ревью, пиши что-то вроде `комментарий студента V.номер итерации`
# </div>
#
# Цвет можно сделать, например, так
#
# <div class = "alert alert-info">
# <h2>Комментарий студента</h2>
# Ревьюер душнила :)
# </div>
#
# Или так:
#
# <div style="background:pink;color:#A91E69">
# <h2>Комментарий студента </h2>
#     ...
#  </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#-Комментарий-ревьюера" data-toc-modified-id="-Комментарий-ревьюера-1"><span class="toc-item-num">1&nbsp;&nbsp;</span> Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-студента" data-toc-modified-id="Комментарий-студента-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Комментарий студента</a></span></li><li><span><a href="#Комментарий-студента-" data-toc-modified-id="Комментарий-студента--3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Комментарий студента </a></span></li><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Пропуски" data-toc-modified-id="Пропуски-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Пропуски</a></span></li></ul></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-13"><span class="toc-item-num">13&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-14"><span class="toc-item-num">14&nbsp;&nbsp;</span>Комментарий ревьюера</a></span><ul class="toc-item"><li><span><a href="#Типы-данных" data-toc-modified-id="Типы-данных-14.1"><span class="toc-item-num">14.1&nbsp;&nbsp;</span>Типы данных</a></span></li><li><span><a href="#Дубликаты" data-toc-modified-id="Дубликаты-14.2"><span class="toc-item-num">14.2&nbsp;&nbsp;</span>Дубликаты</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-14.3"><span class="toc-item-num">14.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-15"><span class="toc-item-num">15&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-16"><span class="toc-item-num">16&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span><ul class="toc-item"><li><span><a href="#Цена-квадратного-метра" data-toc-modified-id="Цена-квадратного-метра-16.1"><span class="toc-item-num">16.1&nbsp;&nbsp;</span>Цена квадратного метра</a></span></li><li><span><a href="#День-недели,-месяц,-год-публикации-объявления" data-toc-modified-id="День-недели,-месяц,-год-публикации-объявления-16.2"><span class="toc-item-num">16.2&nbsp;&nbsp;</span>День недели, месяц, год публикации объявления</a></span></li><li><span><a href="#Этаж:-категория" data-toc-modified-id="Этаж:-категория-16.3"><span class="toc-item-num">16.3&nbsp;&nbsp;</span>Этаж: категория</a></span></li></ul></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-17"><span class="toc-item-num">17&nbsp;&nbsp;</span>Комментарий ревьюера</a></span><ul class="toc-item"><li><span><a href="#Соотношение-площадей" data-toc-modified-id="Соотношение-площадей-17.1"><span class="toc-item-num">17.1&nbsp;&nbsp;</span>Соотношение площадей</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-18"><span class="toc-item-num">18&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Площадь,-цена,-число-комнат,-высота-потолков." data-toc-modified-id="Площадь,-цена,-число-комнат,-высота-потолков.-18.1"><span class="toc-item-num">18.1&nbsp;&nbsp;</span>Площадь, цена, число комнат, высота потолков.</a></span></li></ul></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-19"><span class="toc-item-num">19&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарйи-ревьюера" data-toc-modified-id="Комментарйи-ревьюера-20"><span class="toc-item-num">20&nbsp;&nbsp;</span>Комментарйи ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-21"><span class="toc-item-num">21&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-22"><span class="toc-item-num">22&nbsp;&nbsp;</span>Комментарий ревьюера</a></span><ul class="toc-item"><li><span><a href="#Время-продажи-квартиры" data-toc-modified-id="Время-продажи-квартиры-22.1"><span class="toc-item-num">22.1&nbsp;&nbsp;</span>Время продажи квартиры</a></span></li></ul></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-23"><span class="toc-item-num">23&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-24"><span class="toc-item-num">24&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-25"><span class="toc-item-num">25&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-26"><span class="toc-item-num">26&nbsp;&nbsp;</span>Комментарий ревьюера</a></span><ul class="toc-item"><li><span><a href="#Редкие-и-выбивающиеся-значения" data-toc-modified-id="Редкие-и-выбивающиеся-значения-26.1"><span class="toc-item-num">26.1&nbsp;&nbsp;</span>Редкие и выбивающиеся значения</a></span></li></ul></li><li><span><a href="#Коммеентарий-ревьюера" data-toc-modified-id="Коммеентарий-ревьюера-27"><span class="toc-item-num">27&nbsp;&nbsp;</span>Коммеентарий ревьюера</a></span><ul class="toc-item"><li><span><a href="#Факторы,-больше-всего-влияющие-на-стоимость-квартиры" data-toc-modified-id="Факторы,-больше-всего-влияющие-на-стоимость-квартиры-27.1"><span class="toc-item-num">27.1&nbsp;&nbsp;</span>Факторы, больше всего влияющие на стоимость квартиры</a></span></li></ul></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-28"><span class="toc-item-num">28&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-29"><span class="toc-item-num">29&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-30"><span class="toc-item-num">30&nbsp;&nbsp;</span>Комментарий ревьюера</a></span><ul class="toc-item"><li><span><a href="#Топ-10-населённых-пунктов-с-наибольшим-числом-объявлений" data-toc-modified-id="Топ-10-населённых-пунктов-с-наибольшим-числом-объявлений-30.1"><span class="toc-item-num">30.1&nbsp;&nbsp;</span>Топ-10 населённых пунктов с наибольшим числом объявлений</a></span></li><li><span><a href="#Предложения-квартир-(расстояние-до-центра)" data-toc-modified-id="Предложения-квартир-(расстояние-до-центра)-30.2"><span class="toc-item-num">30.2&nbsp;&nbsp;</span>Предложения квартир (расстояние до центра)</a></span></li></ul></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-31"><span class="toc-item-num">31&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-32"><span class="toc-item-num">32&nbsp;&nbsp;</span>Комментарий ревьюера</a></span><ul class="toc-item"><li><span><a href="#Квартиры-в-центре" data-toc-modified-id="Квартиры-в-центре-32.1"><span class="toc-item-num">32.1&nbsp;&nbsp;</span>Квартиры в центре</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-33"><span class="toc-item-num">33&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-34"><span class="toc-item-num">34&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Комментарий-ревьюера" data-toc-modified-id="Комментарий-ревьюера-35"><span class="toc-item-num">35&nbsp;&nbsp;</span>Комментарий ревьюера</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-36"><span class="toc-item-num">36&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %% [markdown]
# Открыв файл и просмотрев первые его строки, видим, что его разделитель это '\t', поэтому откроем его, указав данный разделитель и просмотрим информацию о данных.

# %%
import pandas as pd 
data=pd.read_csv('/datasets/real_estate_data.csv', sep='\t', decimal=',')

# %%
pd.options.display.max_columns=40
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null object
# total_area              23699 non-null object
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null object
# floors_total            23613 non-null object
# living_area             21796 non-null object
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null object
# balcony                 12180 non-null object
# locality_name           23650 non-null object
# airports_nearest        18157 non-null object
# cityCenters_nearest     18180 non-null object
# parks_around3000        18181 non-null object
# parks_nearest           8079 non-null object
# ponds_around3000        18181 non-null object
# ponds_nearest           9110 non-null object
# days_exposition         20518 non-null object
# dtypes: bool(2), int64(3), object(17)
# memory usage: 3.7+ MB

# %%
data.head(10)
# Out:
#    total_images  last_price total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.0  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.4  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.3  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.6  2019-04-18T00:00:00      2
# 8            20   2900000.0      33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.0  2017-02-26T00:00:00      3
#
#   ceiling_height floors_total living_area  floor is_apartment  studio  \
# 0            2.7         16.0        51.0      8          NaN   False
# 1            NaN         11.0        18.6      1          NaN   False
# 2            NaN          5.0        34.3      4          NaN   False
# 3            NaN         14.0         NaN      9          NaN   False
# 4           3.03         14.0        32.0     13          NaN   False
# 5            NaN         12.0        14.4      5          NaN   False
# 6            NaN         26.0        10.6      6          NaN   False
# 7            NaN         24.0         NaN     22          NaN   False
# 8            NaN         27.0       15.43     26          NaN   False
# 9            2.5          9.0        43.6      7          NaN   False
#
#    open_plan kitchen_area balcony              locality_name airports_nearest  \
# 0      False         25.0     NaN            Санкт-Петербург          18863.0
# 1      False         11.0     2.0             посёлок Шушары          12817.0
# 2      False          8.3     0.0            Санкт-Петербург          21741.0
# 3      False          NaN     0.0            Санкт-Петербург          28098.0
# 4      False         41.0     NaN            Санкт-Петербург          31856.0
# 5      False          9.1     NaN  городской посёлок Янино-1              NaN
# 6      False         14.4     1.0          посёлок Парголово          52996.0
# 7      False         18.9     2.0            Санкт-Петербург          23982.0
# 8      False         8.81     NaN             посёлок Мурино              NaN
# 9      False          6.5     2.0            Санкт-Петербург          50898.0
#
#   cityCenters_nearest parks_around3000 parks_nearest ponds_around3000  \
# 0             16028.0              1.0         482.0              2.0
# 1             18603.0              0.0           NaN              0.0
# 2             13933.0              1.0          90.0              2.0
# 3              6800.0              2.0          84.0              3.0
# 4              8098.0              2.0         112.0              1.0
# 5                 NaN              NaN           NaN              NaN
# 6             19143.0              0.0           NaN              0.0
# 7             11634.0              0.0           NaN              0.0
# 8                 NaN              NaN           NaN              NaN
# 9             15008.0              0.0           NaN              0.0
#
#   ponds_nearest     days_exposition
# 0         755.0                 NaN
# 1           NaN                81.0
# 2         574.0               558.0
# 3         234.0               424.0
# 4          48.0               121.0
# 5           NaN                55.0
# 6           NaN               155.0
# 7           NaN                 NaN
# 8           NaN  189.00000000000003
# 9           NaN               289.0

# %% [markdown]
# ### Вывод

# %% [markdown]
# Видим общее число записей: 23699 записей, все столбцы названы корректно, переименование не требуется. В некоторых столбцах существуют пропуски данных (высота потолков, жилая площадь, всего этажей в доме, апартаменты ли, площадь кухни, наличие балкона, расстояние до центра, расстояние до ближайшего парка, водоема, количество дней, пока публиковалось объявление и т.д.), требуется работа с пропусками.
# Некоторые столбцы имеют некорректный формат данных (цена продажи, общая площадь, дата опубликования, высота потолков, всего этажей, общая площаь, апартаменты ли, площадь кухни, кол-во балконов, расстояние до аэропорта, парка, водоема и т.д. - все это строки вместо чисел), требуется работа с форматами данных.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Пропуски

# %% [markdown]
# 1. В столбцах total_images, last_price, total_area, first_day_exposition и rooms пропусков нет. Посмотрим в первом приближении на данные о цене, площади и дате размещения объявления.

# %% [markdown]
# Напишем функцию общего описания столбца с числовыми данными и будем использовать для других столбцов в дальнейшем.

# %%
def max_min_description (column_name): 
    print('Столбец:', column_name)
    print('Минимум', data[column_name].min())
    print('Медиана', data[column_name].median())
    print('Среднее', data[column_name].mean())
    print('Максимум', data[column_name].max())

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# В pandas `describe` делает то же самое :)
# </div>

# %%
data['last_price']=pd.to_numeric(data['last_price'])
max_min_description('last_price')
# Out:
# Столбец: last_price
# Минимум 12190.0
# Медиана 4650000.0
# Среднее 6541548.771551542
# Максимум 763000000.0

# %% [markdown]
# Видим, что в данных о цене есть необычайно низкие и необычайно высокие значения. Изучим их подробнее на шаге построения диаграмм. Цена - это один из ключевых столбцов, и необходимо его подробно исследовать. То же касается и площади (общей, а также квадратного метра):

# %%
data['total_area']=pd.to_numeric(data['total_area'])
max_min_description('total_area')
# Out:
# Столбец: total_area
# Минимум 12.0
# Медиана 52.0
# Среднее 60.34865099793241
# Максимум 900.0

# %% [markdown]
# 2. В столбце ceiling_height есть большое количество пропущенных данных, также формат данных в этом столбце - object.

# %%
data['ceiling_height'].isnull().sum()
# Out:
# 9195

# %%
data['ceiling_height']=pd.to_numeric(data['ceiling_height'])
max_min_description('ceiling_height')
# Out:
# Столбец: ceiling_height
# Минимум 1.0
# Медиана 2.65
# Среднее 2.77149889685604
# Максимум 100.0

# %% [markdown]
# Максимальное значение выглядит странно (вряд ли высота потолка в каком-либо жилом помещении будет 100 метров), а медиана в размере 2.65 - стандартная. Заменим пропущенные значения медианными.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Высота потолка зависит во многом от типа жилья, поэтому возможно не стоит заменять медианой
# </div>

# %%
data['ceiling_height']=data['ceiling_height'].fillna(data['ceiling_height'].median())

# %%
data['ceiling_height'].isnull().sum()
# Out:
# 0

# %% [markdown]
# 3. В столбце floors_total также есть пропуски. Их незначительное количество. Поступим аналогично.

# %%
data['floors_total'].isnull().sum()
# Out:
# 86

# %%
data['floors_total']=pd.to_numeric(data['floors_total'])
max_min_description('floors_total')
# Out:
# Столбец: floors_total
# Минимум 1.0
# Медиана 9.0
# Среднее 10.67382374115953
# Максимум 60.0

# %%
data['floors_total']=data['floors_total'].fillna(data['floors_total'].median())

# %%
data['floors_total'].isnull().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-warning">
# <h2>Комментарий ревьюера</h2>
#
# Тут аналогично как с потолками, теперь в некоторых квартирах этаж квартиры выше этажности дома :)
# </div>

# %%
data[data['floor'] > data['floors_total']]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 457               4  9788348.00       70.80  2015-08-01T00:00:00      2
# 2392              7  5395770.00       53.00  2017-06-29T00:00:00      2
# 2846              4  2325000.00       27.80  2016-09-21T00:00:00      1
# 3031              9  6400000.00       56.70  2018-03-27T00:00:00      2
# 3438             10  4100000.00       38.00  2018-04-14T00:00:00      1
# 4617              4  4275062.00       61.20  2017-04-27T00:00:00      2
# 4848             15 13000000.00       98.00  2017-02-08T00:00:00      3
# 5146             10  3085024.00       33.33  2018-10-06T00:00:00      1
# 5187              5  3300000.00       25.40  2018-11-02T00:00:00      0
# 5784              4  4262941.00       59.90  2017-04-02T00:00:00      2
# 5958              1  3200000.00       30.30  2018-09-07T00:00:00      0
# 6030              3 10900000.00      116.23  2017-05-05T00:00:00      4
# 7922              3  5426412.00       50.11  2016-06-08T00:00:00      2
# 8478             19 13500000.00       77.80  2019-04-17T00:00:00      2
# 9023              5  2900000.00       35.10  2018-07-18T00:00:00      1
# 10013             4  4558637.00       64.40  2016-09-21T00:00:00      2
# 10027             4  4650259.00       67.50  2017-04-01T00:00:00      2
# 10058             9  3350000.00       25.00  2018-09-10T00:00:00      1
# 10531             3  6595420.00       61.80  2016-05-21T00:00:00      2
# 10983             6  4670000.00       37.80  2019-03-13T00:00:00      1
# 11129            10  3128418.00       34.53  2018-10-01T00:00:00      1
# 13438             4  4403541.00       65.30  2016-09-21T00:00:00      2
# 13622             3  7650000.00       88.84  2016-05-21T00:00:00      3
# 14094             5  3290000.00       33.00  2018-02-01T00:00:00      1
# 14264            13 14000000.00       94.00  2019-01-23T00:00:00      6
# 14526             1  5595000.00       52.47  2016-03-23T00:00:00      2
# 16591             8  4500000.00       37.60  2018-07-10T00:00:00      1
# 16850             4  6188957.00       90.20  2016-09-21T00:00:00      3
# 17498             4  4252249.00       60.20  2017-04-01T00:00:00      2
# 19452             5  9500000.00       76.80  2019-04-11T00:00:00      3
# 20146            16  3850000.00       36.00  2018-10-12T00:00:00      1
# 20738             5  4480000.00       54.22  2018-02-01T00:00:00      2
# 21273             3  6300000.00       70.02  2015-03-28T00:00:00      2
# 21651             4  7143060.00       44.70  2019-01-11T00:00:00      1
# 21753             7  6800000.00       57.00  2017-05-01T00:00:00      2
# 22656             4  4574160.00       64.50  2017-04-02T00:00:00      2
# 23590             0 21187872.00      123.30  2017-04-25T00:00:00      3
#
#        ceiling_height  floors_total living_area  floor is_apartment  studio  \
# 457              2.65          9.00        38.4     12          NaN   False
# 2392             2.65          9.00        29.0     22          NaN   False
# 2846             2.65          9.00        19.4     15          NaN   False
# 3031             2.65          9.00        32.0     12          NaN   False
# 3438             2.65          9.00        19.0     12          NaN   False
# 4617             2.65          9.00        32.0     12          NaN   False
# 4848             2.65          9.00         NaN     18          NaN   False
# 5146             2.65          9.00        11.0     12          NaN   False
# 5187             2.65          9.00         NaN     15          NaN    True
# 5784             2.65          9.00        31.7     18          NaN   False
# 5958             2.65          9.00         NaN     13          NaN    True
# 6030             2.65          9.00         NaN     24          NaN   False
# 7922             2.65          9.00       26.94     24          NaN   False
# 8478             2.80          9.00       39.41     21          NaN   False
# 9023             2.65          9.00         NaN     11          NaN   False
# 10013            2.65          9.00        31.7     19          NaN   False
# 10027            2.65          9.00        31.3     20          NaN   False
# 10058            2.65          9.00        17.0     21          NaN   False
# 10531            2.65          9.00       30.01     12          NaN   False
# 10983            2.65          9.00        16.9     14          NaN   False
# 11129            2.65          9.00        11.0     13          NaN   False
# 13438            2.65          9.00        31.6     11          NaN   False
# 13622            2.65          9.00       49.87     21          NaN   False
# 14094            2.65          9.00         NaN     17          NaN   False
# 14264            2.65          9.00        51.0     23          NaN   False
# 14526            2.65          9.00         NaN     10          NaN   False
# 16591            2.65          9.00        17.5     11          NaN   False
# 16850            2.65          9.00        47.7     14          NaN   False
# 17498            2.65          9.00        31.8     13          NaN   False
# 19452            2.65          9.00         NaN     10          NaN   False
# 20146            2.65          9.00        19.0     15          NaN   False
# 20738            2.65          9.00         NaN     10          NaN   False
# 21273            2.65          9.00       34.87     19          NaN   False
# 21651            3.00          9.00       13.79     19          NaN   False
# 21753            2.65          9.00         NaN     21          NaN   False
# 22656            2.65          9.00        31.7     20          NaN   False
# 23590            2.65          9.00        50.4     18          NaN   False
#
#        open_plan kitchen_area balcony                locality_name  \
# 457        False        10.63     0.0              Санкт-Петербург
# 2392       False          9.0     0.0              Санкт-Петербург
# 2846       False          NaN     0.0              Санкт-Петербург
# 3031       False         12.0     NaN                      Кудрово
# 3438       False         10.3     NaN                      Кудрово
# 4617       False         12.2     0.0              Санкт-Петербург
# 4848       False          NaN     0.0              Санкт-Петербург
# 5146       False          NaN     NaN              Санкт-Петербург
# 5187       False          NaN     NaN               посёлок Мурино
# 5784       False         11.9     0.0              Санкт-Петербург
# 5958       False          NaN     NaN              Санкт-Петербург
# 6030       False          NaN     0.0              Санкт-Петербург
# 7922       False        11.13     0.0              Санкт-Петербург
# 8478       False        13.27     2.0              Санкт-Петербург
# 9023       False          NaN     NaN  городской посёлок Новоселье
# 10013      False         14.4     0.0              Санкт-Петербург
# 10027      False         14.4     0.0              Санкт-Петербург
# 10058      False          3.5     NaN               посёлок Шушары
# 10531      False        10.08     0.0              Санкт-Петербург
# 10983      False          9.5     NaN              Санкт-Петербург
# 11129      False          NaN     NaN              Санкт-Петербург
# 13438      False         12.2     0.0              Санкт-Петербург
# 13622      False         9.76     0.0              Санкт-Петербург
# 14094      False          NaN     NaN      деревня Новое Девяткино
# 14264      False         16.3     NaN              Санкт-Петербург
# 14526      False          NaN     0.0              Санкт-Петербург
# 16591      False         11.0     NaN              Санкт-Петербург
# 16850      False         16.7     0.0              Санкт-Петербург
# 17498      False         12.1     0.0              Санкт-Петербург
# 19452      False          NaN     NaN              Санкт-Петербург
# 20146      False          8.5     NaN             посёлок Стрельна
# 20738      False          NaN     NaN               посёлок Мурино
# 21273      False        10.13     0.0              Санкт-Петербург
# 21651      False          NaN     NaN              Санкт-Петербург
# 21753      False          NaN     0.0              Санкт-Петербург
# 22656      False         14.4     0.0              Санкт-Петербург
# 23590      False         23.6     0.0              Санкт-Петербург
#
#       airports_nearest cityCenters_nearest parks_around3000 parks_nearest  \
# 457            37364.0              8322.0              2.0         309.0
# 2392           43074.0             10820.0              0.0           NaN
# 2846           22041.0             17369.0              0.0           NaN
# 3031               NaN                 NaN              NaN           NaN
# 3438               NaN                 NaN              NaN           NaN
# 4617           22041.0             17369.0              0.0           NaN
# 4848           37625.0             14153.0              0.0           NaN
# 5146           47303.0             25865.0              1.0         400.0
# 5187               NaN                 NaN              NaN           NaN
# 5784           22041.0             17369.0              0.0           NaN
# 5958           22735.0             11618.0              1.0         835.0
# 6030           35234.0             14674.0              0.0           NaN
# 7922            7050.0             13266.0              1.0         868.0
# 8478           12838.0             11477.0              1.0         593.0
# 9023               NaN                 NaN              NaN           NaN
# 10013          22041.0             17369.0              0.0           NaN
# 10027          22041.0             17369.0              0.0           NaN
# 10058              NaN                 NaN              NaN           NaN
# 10531           7050.0             13266.0              1.0         868.0
# 10983          23982.0             11634.0              0.0           NaN
# 11129          47303.0             25865.0              1.0         400.0
# 13438          22041.0             17369.0              0.0           NaN
# 13622          35234.0             14674.0              0.0           NaN
# 14094              NaN                 NaN              NaN           NaN
# 14264          51333.0             13056.0              0.0           NaN
# 14526           7050.0             13266.0              1.0         868.0
# 16591          37625.0             14153.0              0.0           NaN
# 16850          22041.0             17369.0              0.0           NaN
# 17498          22041.0             17369.0              0.0           NaN
# 19452          36628.0             14780.0              0.0           NaN
# 20146          28276.0             23454.0              0.0           NaN
# 20738              NaN                 NaN              NaN           NaN
# 21273          35234.0             14674.0              0.0           NaN
# 21651           9222.0             11340.0              0.0           NaN
# 21753          17618.0             14600.0              2.0         104.0
# 22656          22041.0             17369.0              0.0           NaN
# 23590          19095.0              4529.0              0.0           NaN
#
#       ponds_around3000 ponds_nearest     days_exposition
# 457                2.0         706.0   727.0000000000001
# 2392               0.0           NaN   48.00000000000001
# 2846               1.0         374.0               307.0
# 3031               NaN           NaN               231.0
# 3438               NaN           NaN                95.0
# 4617               1.0         374.0                72.0
# 4848               0.0           NaN                29.0
# 5146               1.0         492.0               140.0
# 5187               NaN           NaN  3.0000000000000004
# 5784               1.0         374.0               127.0
# 5958               1.0         652.0                68.0
# 6030               1.0         844.0                83.0
# 7922               0.0           NaN                14.0
# 8478               1.0         130.0                 NaN
# 9023               NaN           NaN                26.0
# 10013              1.0         374.0               320.0
# 10027              1.0         374.0               116.0
# 10058              NaN           NaN  23.000000000000004
# 10531              0.0           NaN               112.0
# 10983              0.0           NaN                 NaN
# 11129              1.0         492.0               145.0
# 13438              1.0         374.0               320.0
# 13622              1.0         844.0                42.0
# 14094              NaN           NaN               440.0
# 14264              0.0           NaN                 NaN
# 14526              0.0           NaN   90.00000000000001
# 16591              0.0           NaN                 8.0
# 16850              1.0         374.0               320.0
# 17498              1.0         374.0               128.0
# 19452              0.0           NaN                 NaN
# 20146              0.0           NaN  183.00000000000003
# 20738              NaN           NaN                42.0
# 21273              1.0         844.0               516.0
# 21651              0.0           NaN                 NaN
# 21753              0.0           NaN                36.0
# 22656              1.0         374.0               127.0
# 23590              0.0           NaN               104.0

# %% [markdown]
# 4. В столбце living_area также есть пропуски. Их нельзя заменить на среднее, т.к. для жилой площади есть ограничение - общая площадь. Найдем отношение жилой площади к общей площади для тех строк, где нет пропусков, затем внесем это значение в новый столбец, найдем медианный показатель и используем его - в обратном порядке, умножая на него общую площадь - для заполнения пропусков в данных жилой площади, ведь данные об общей площади заполнены все.

# %%
data['living_area'].isna().sum()
# Out:
# 1903

# %%
data['living_area']=pd.to_numeric(data['living_area'])

# %%
data['living_area_ratio']=data['living_area'] / data['total_area']
median_living_area_ratio=data['living_area_ratio'].median()
median_living_area_ratio
# Out:
# 0.5678598992678503

# %%
data['living_area']=data['living_area'].fillna(data['total_area']*median_living_area_ratio)
data['living_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Всё верно 👍
# </div>

# %%
max_min_description('living_area')
# Out:
# Столбец: living_area
# Минимум 2.0
# Медиана 30.0
# Среднее 34.57821382649988
# Максимум 409.7

# %% [markdown]
# 5. Столбец is_apartment должен иметь булев тип, то есть True/False. Посмотрим, какие данные указаны и почему тип данных object.

# %%
data['is_apartment'].isna().sum()
# Out:
# 20924

# %%
data['is_apartment'].value_counts()
# Out:
# False    2725
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# На самом деле апартаментов вообще немного, поэтому сочтем, что там, где этот столбец не заполнен, это означает "не апартаменты" и заменим пропущенные значения на False.

# %%
data['is_apartment']=data['is_apartment'].fillna(False)
data['is_apartment'].isna().sum()
# Out:
# 0

# %%
data['is_apartment'].value_counts()
# Out:
# False    23649
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# 6. С пропущенными данными в kitchen_area поступим аналогично living_area

# %%
data['kitchen_area'].isna().sum()
# Out:
# 2278

# %%
data['kitchen_area']=pd.to_numeric(data['kitchen_area'])

# %%
data['kitchen_area_ratio']=data['kitchen_area'] / data['total_area']
median_kitchen_area_ratio=data['kitchen_area_ratio'].median()
median_kitchen_area_ratio
# Out:
# 0.1724137931034483

# %%
data['kitchen_area']=data['kitchen_area'].fillna(data['total_area']*median_kitchen_area_ratio)
data['kitchen_area'].isna().sum()
# Out:
# 0

# %%
max_min_description('kitchen_area')
# Out:
# Столбец: kitchen_area
# Минимум 1.3
# Медиана 9.0
# Среднее 10.49143112396711
# Максимум 112.0

# %% [markdown]
# 7. С данными в balcony поступим аналогично с данными в apartment. Вероятнее всего, данные о балконе не заполнены потому, что балкона нет.

# %%
data['balcony'].isna().sum()
# Out:
# 11519

# %%
data['balcony'].value_counts()
# Out:
# 1.0    4195
# 0.0    3758
# 2.0    3659
# 5.0     304
# 4.0     183
# 3.0      81
# Name: balcony, dtype: int64

# %%
data['balcony']=data['balcony'].fillna(0)
data['balcony'].isna().sum()
# Out:
# 0

# %%
data['balcony']=pd.to_numeric(data['balcony'])
data['balcony'].value_counts()
# Out:
# 0.00    15277
# 1.00     4195
# 2.00     3659
# 5.00      304
# 4.00      183
# 3.00       81
# Name: balcony, dtype: int64

# %% [markdown]
# 8. Незаполненные данные в столбце locality_name

# %%
data['locality_name'].isna().sum()
# Out:
# 49

# %% [markdown]
# Ради 49 записей можно было и не создавать такой алгоритм, и просто указать "Санкт-Петербург", но посмотрим, какие значения принимает для них расстояние до центра.

# %%
data['locality_name']=data['locality_name'].fillna('Неизвестно')

# %%
data['cityCenters_nearest']=pd.to_numeric(data['cityCenters_nearest'])
data_unknown_locality=data.query('locality_name=="Неизвестно"')
print('От', data_unknown_locality['cityCenters_nearest'].min(), ', до', data_unknown_locality['cityCenters_nearest'].max())
# Out:
# От 1322.0 , до 41294.0

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# В таких случаях лучше не менять `nan` на строку, а проверить с помощью `isna()`. Вместо `query` лучше пользоваться индексацией с `[]`, в ней сложнее опечататься и можно пользоваться автодополнением (в юпитере на таб) `data_unknown_locality = data[data[locality_name].isna()]`
# </div>

# %% [markdown]
# Поймем, какое расстояние до центра у тех записей, центром которых указан Санкт-Петербург.

# %%
data_spb_locality=data.query('locality_name=="Санкт-Петербург"')
print('От', data_spb_locality['cityCenters_nearest'].min(), 'до', data_spb_locality['cityCenters_nearest'].max())
# Out:
# От 181.0 до 29493.0

# %% [markdown]
# Узнаем, сколько записей с неизвестным центром дальше, чем самая дальняя от центра города квартира.

# %%
data_unknown_locality.query('cityCenters_nearest>29493.0')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 8986             10  4850000.00      103.10  2018-07-10T00:00:00      3
# 21119             8  3500000.00       43.20  2018-11-11T00:00:00      2
# 21276             0 17122148.00      178.30  2017-02-10T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 8986             2.65          9.00        68.10      4         False   False
# 21119            2.65          4.00        24.53      2         False   False
# 21276            2.65          3.00       101.25      1         False   False
#
#        open_plan  kitchen_area  balcony locality_name airports_nearest  \
# 8986       False         16.70     0.00    Неизвестно          19659.0
# 21119      False          7.45     0.00    Неизвестно          19744.0
# 21276      False         41.60     1.00    Неизвестно          60195.0
#
#        cityCenters_nearest parks_around3000 parks_nearest ponds_around3000  \
# 8986              31813.00              0.0           NaN              0.0
# 21119             31897.00              0.0           NaN              0.0
# 21276             41294.00              0.0           NaN              0.0
#
#       ponds_nearest days_exposition  living_area_ratio  kitchen_area_ratio
# 8986            NaN            28.0               0.66                0.16
# 21119           NaN             9.0                nan                 nan
# 21276           NaN             4.0                nan                0.23

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Тут вместо константы можно было вставить `data_spb_locality['cityCenters_nearest'].max()`, а то вдруг данные изменяться или ошибка найдётся, придётся переписывать
# </div>

# %% [markdown]
# Их всего три, поэтому для всех данных, где населенный пункт не указан, укажем "Санкт-Петербург".

# %%
data.loc[data['locality_name']=='Неизвестно', 'locality_name']='Санкт-Петербург'

# %%
data['locality_name'].value_counts()
# Out:
# Санкт-Петербург           15770
# посёлок Мурино              522
# посёлок Шушары              440
# Всеволожск                  398
# Пушкин                      369
#                           ...
# поселок Почап                 1
# посёлок Высокоключевой        1
# посёлок Ропша                 1
# деревня Щеглово               1
# деревня Нижние Осельки        1
# Name: locality_name, Length: 364, dtype: int64

# %%
data['locality_name'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Классная идея с алгоритмом замены 👍
# </div>

# %% [markdown]
# Теперь проверим дубликаты в названиях населенных пунктов. Они возможны там из-за разницы написания названий.

# %%
locality_name_list=data['locality_name'].unique().tolist()
locality_name_list
# Out:
# ['Санкт-Петербург',
#  'посёлок Шушары',
#  'городской посёлок Янино-1',
#  'посёлок Парголово',
#  'посёлок Мурино',
#  'Ломоносов',
#  'Сертолово',
#  'Петергоф',
#  'Пушкин',
#  'деревня Кудрово',
#  'Коммунар',
#  'Колпино',
#  'поселок городского типа Красный Бор',
#  'Гатчина',
#  'поселок Мурино',
#  'деревня Фёдоровское',
#  'Выборг',
#  'Кронштадт',
#  'Кировск',
#  'деревня Новое Девяткино',
#  'посёлок Металлострой',
#  'посёлок городского типа Лебяжье',
#  'посёлок городского типа Сиверский',
#  'поселок Молодцово',
#  'поселок городского типа Кузьмоловский',
#  'садовое товарищество Новая Ропша',
#  'Павловск',
#  'деревня Пикколово',
#  'Всеволожск',
#  'Волхов',
#  'Кингисепп',
#  'Приозерск',
#  'Сестрорецк',
#  'деревня Куттузи',
#  'посёлок Аннино',
#  'поселок городского типа Ефимовский',
#  'посёлок Плодовое',
#  'деревня Заклинье',
#  'поселок Торковичи',
#  'поселок Первомайское',
#  'Красное Село',
#  'посёлок Понтонный',
#  'Сясьстрой',
#  'деревня Старая',
#  'деревня Лесколово',
#  'посёлок Новый Свет',
#  'Сланцы',
#  'село Путилово',
#  'Ивангород',
#  'Мурино',
#  'Шлиссельбург',
#  'Никольское',
#  'Зеленогорск',
#  'Сосновый Бор',
#  'поселок Новый Свет',
#  'деревня Оржицы',
#  'деревня Кальтино',
#  'Кудрово',
#  'поселок Романовка',
#  'посёлок Бугры',
#  'поселок Бугры',
#  'поселок городского типа Рощино',
#  'Кириши',
#  'Луга',
#  'Волосово',
#  'Отрадное',
#  'село Павлово',
#  'поселок Оредеж',
#  'село Копорье',
#  'посёлок городского типа Красный Бор',
#  'посёлок Молодёжное',
#  'Тихвин',
#  'посёлок Победа',
#  'деревня Нурма',
#  'поселок городского типа Синявино',
#  'Тосно',
#  'посёлок городского типа Кузьмоловский',
#  'посёлок Стрельна',
#  'Бокситогорск',
#  'посёлок Александровская',
#  'деревня Лопухинка',
#  'Пикалёво',
#  'поселок Терволово',
#  'поселок городского типа Советский',
#  'Подпорожье',
#  'посёлок Петровское',
#  'посёлок городского типа Токсово',
#  'поселок Сельцо',
#  'посёлок городского типа Вырица',
#  'деревня Кипень',
#  'деревня Келози',
#  'деревня Вартемяги',
#  'посёлок Тельмана',
#  'поселок Севастьяново',
#  'городской поселок Большая Ижора',
#  'городской посёлок Павлово',
#  'деревня Агалатово',
#  'посёлок Новогорелово',
#  'городской посёлок Лесогорский',
#  'деревня Лаголово',
#  'поселок Цвелодубово',
#  'поселок городского типа Рахья',
#  'поселок городского типа Вырица',
#  'деревня Белогорка',
#  'поселок Заводской',
#  'городской посёлок Новоселье',
#  'деревня Большие Колпаны',
#  'деревня Горбунки',
#  'деревня Батово',
#  'деревня Заневка',
#  'деревня Иссад',
#  'Приморск',
#  'городской посёлок Фёдоровское',
#  'деревня Мистолово',
#  'Новая Ладога',
#  'поселок Зимитицы',
#  'поселок Барышево',
#  'деревня Разметелево',
#  'поселок городского типа имени Свердлова',
#  'деревня Пеники',
#  'поселок Рябово',
#  'деревня Пудомяги',
#  'поселок станции Корнево',
#  'деревня Низино',
#  'деревня Бегуницы',
#  'посёлок Поляны',
#  'городской посёлок Мга',
#  'поселок Елизаветино',
#  'посёлок городского типа Кузнечное',
#  'деревня Колтуши',
#  'поселок Запорожское',
#  'посёлок городского типа Рощино',
#  'деревня Гостилицы',
#  'деревня Малое Карлино',
#  'посёлок Мичуринское',
#  'посёлок городского типа имени Морозова',
#  'посёлок Песочный',
#  'посёлок Сосново',
#  'деревня Аро',
#  'поселок Ильичёво',
#  'посёлок городского типа Тайцы',
#  'деревня Малое Верево',
#  'деревня Извара',
#  'поселок станции Вещево',
#  'село Паша',
#  'деревня Калитино',
#  'посёлок городского типа Ульяновка',
#  'деревня Чудской Бор',
#  'поселок городского типа Дубровка',
#  'деревня Мины',
#  'поселок Войсковицы',
#  'посёлок городского типа имени Свердлова',
#  'деревня Коркино',
#  'посёлок Ропша',
#  'поселок городского типа Приладожский',
#  'посёлок Щеглово',
#  'посёлок Гаврилово',
#  'Лодейное Поле',
#  'деревня Рабитицы',
#  'поселок городского типа Никольский',
#  'деревня Кузьмолово',
#  'деревня Малые Колпаны',
#  'поселок Тельмана',
#  'посёлок Петро-Славянка',
#  'городской посёлок Назия',
#  'посёлок Репино',
#  'посёлок Ильичёво',
#  'поселок Углово',
#  'поселок Старая Малукса',
#  'садовое товарищество Рахья',
#  'поселок Аннино',
#  'поселок Победа',
#  'деревня Меньково',
#  'деревня Старые Бегуницы',
#  'посёлок Сапёрный',
#  'поселок Семрино',
#  'поселок Гаврилово',
#  'поселок Глажево',
#  'поселок Кобринское',
#  'деревня Гарболово',
#  'деревня Юкки',
#  'поселок станции Приветнинское',
#  'деревня Мануйлово',
#  'деревня Пчева',
#  'поселок Поляны',
#  'поселок Цвылёво',
#  'поселок Мельниково',
#  'посёлок Пудость',
#  'посёлок Усть-Луга',
#  'Светогорск',
#  'Любань',
#  'поселок Селезнёво',
#  'поселок городского типа Рябово',
#  'Каменногорск',
#  'деревня Кривко',
#  'поселок Глебычево',
#  'деревня Парицы',
#  'поселок Жилпосёлок',
#  'посёлок городского типа Мга',
#  'городской поселок Янино-1',
#  'посёлок Войскорово',
#  'село Никольское',
#  'посёлок Терволово',
#  'поселок Стеклянный',
#  'посёлок городского типа Важины',
#  'посёлок Мыза-Ивановка',
#  'село Русско-Высоцкое',
#  'поселок городского типа Лебяжье',
#  'поселок городского типа Форносово',
#  'село Старая Ладога',
#  'поселок Житково',
#  'городской посёлок Виллози',
#  'деревня Лампово',
#  'деревня Шпаньково',
#  'деревня Лаврики',
#  'посёлок Сумино',
#  'посёлок Возрождение',
#  'деревня Старосиверская',
#  'посёлок Кикерино',
#  'поселок Возрождение',
#  'деревня Старое Хинколово',
#  'посёлок Пригородный',
#  'посёлок Торфяное',
#  'городской посёлок Будогощь',
#  'поселок Суходолье',
#  'поселок Красная Долина',
#  'деревня Хапо-Ое',
#  'поселок городского типа Дружная Горка',
#  'поселок Лисий Нос',
#  'деревня Яльгелево',
#  'посёлок Стеклянный',
#  'село Рождествено',
#  'деревня Старополье',
#  'посёлок Левашово',
#  'деревня Сяськелево',
#  'деревня Камышовка',
#  'садоводческое некоммерческое товарищество Лесная Поляна',
#  'деревня Хязельки',
#  'поселок Жилгородок',
#  'посёлок городского типа Павлово',
#  'деревня Ялгино',
#  'поселок Новый Учхоз',
#  'городской посёлок Рощино',
#  'поселок Гончарово',
#  'поселок Почап',
#  'посёлок Сапёрное',
#  'посёлок Платформа 69-й километр',
#  'поселок Каложицы',
#  'деревня Фалилеево',
#  'деревня Пельгора',
#  'поселок городского типа Лесогорский',
#  'деревня Торошковичи',
#  'посёлок Белоостров',
#  'посёлок Алексеевка',
#  'поселок Серебрянский',
#  'поселок Лукаши',
#  'поселок Петровское',
#  'деревня Щеглово',
#  'поселок Мичуринское',
#  'деревня Тарасово',
#  'поселок Кингисеппский',
#  'посёлок при железнодорожной станции Вещево',
#  'поселок Ушаки',
#  'деревня Котлы',
#  'деревня Сижно',
#  'деревня Торосово',
#  'посёлок Форт Красная Горка',
#  'поселок городского типа Токсово',
#  'деревня Новолисино',
#  'посёлок станции Громово',
#  'деревня Глинка',
#  'посёлок Мельниково',
#  'поселок городского типа Назия',
#  'деревня Старая Пустошь',
#  'поселок Коммунары',
#  'поселок Починок',
#  'посёлок городского типа Вознесенье',
#  'деревня Разбегаево',
#  'посёлок городского типа Рябово',
#  'поселок Гладкое',
#  'посёлок при железнодорожной станции Приветнинское',
#  'поселок Тёсово-4',
#  'посёлок Жилгородок',
#  'деревня Бор',
#  'посёлок Коробицыно',
#  'деревня Большая Вруда',
#  'деревня Курковицы',
#  'посёлок Лисий Нос',
#  'городской посёлок Советский',
#  'посёлок Кобралово',
#  'деревня Суоранда',
#  'поселок Кобралово',
#  'поселок городского типа Кондратьево',
#  'коттеджный поселок Счастье',
#  'поселок Любань',
#  'деревня Реброво',
#  'деревня Зимитицы',
#  'деревня Тойворово',
#  'поселок Семиозерье',
#  'поселок Лесное',
#  'поселок Совхозный',
#  'поселок Усть-Луга',
#  'посёлок Ленинское',
#  'посёлок Суйда',
#  'посёлок городского типа Форносово',
#  'деревня Нижние Осельки',
#  'посёлок станции Свирь',
#  'поселок Перово',
#  'Высоцк',
#  'поселок Гарболово',
#  'село Шум',
#  'поселок Котельский',
#  'поселок станции Лужайка',
#  'деревня Большая Пустомержа',
#  'поселок Красносельское',
#  'деревня Вахнова Кара',
#  'деревня Пижма',
#  'коттеджный поселок Кивеннапа Север',
#  'поселок Коробицыно',
#  'поселок Ромашки',
#  'посёлок Перово',
#  'деревня Каськово',
#  'деревня Куровицы',
#  'посёлок Плоское',
#  'поселок Сумино',
#  'поселок городского типа Большая Ижора',
#  'поселок Кирпичное',
#  'деревня Ям-Тесово',
#  'деревня Раздолье',
#  'деревня Терпилицы',
#  'посёлок Шугозеро',
#  'деревня Ваганово',
#  'поселок Пушное',
#  'садовое товарищество Садко',
#  'посёлок Усть-Ижора',
#  'деревня Выскатка',
#  'городской посёлок Свирьстрой',
#  'поселок Громово',
#  'деревня Кисельня',
#  'посёлок Старая Малукса',
#  'деревня Трубников Бор',
#  'поселок Калитино',
#  'посёлок Высокоключевой',
#  'садовое товарищество Приладожский',
#  'посёлок Пансионат Зелёный Бор',
#  'деревня Ненимяки',
#  'поселок Пансионат Зелёный Бор',
#  'деревня Снегирёвка',
#  'деревня Рапполово',
#  'деревня Пустынка',
#  'поселок Рабитицы',
#  'деревня Большой Сабск',
#  'деревня Русско',
#  'деревня Лупполово',
#  'деревня Большое Рейзино',
#  'деревня Малая Романовка',
#  'поселок Дружноселье',
#  'поселок Пчевжа',
#  'поселок Володарское',
#  'деревня Нижняя',
#  'коттеджный посёлок Лесное',
#  'деревня Тихковицы',
#  'деревня Борисова Грива',
#  'посёлок Дзержинского']

# %%
len(data['locality_name'].unique().tolist())
# Out:
# 364

# %% [markdown]
# Очевидно, что дубликаты есть из-за букв "е" и "ё". Например, "посёлок Пансионат Зелёный Бор" и др.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# 👍
# </div>

# %%
data['locality_name']=data['locality_name'].str.replace('ё', 'е', regex=True)

# %%
data['locality_name'].unique().tolist()
# Out:
# ['Санкт-Петербург',
#  'поселок Шушары',
#  'городской поселок Янино-1',
#  'поселок Парголово',
#  'поселок Мурино',
#  'Ломоносов',
#  'Сертолово',
#  'Петергоф',
#  'Пушкин',
#  'деревня Кудрово',
#  'Коммунар',
#  'Колпино',
#  'поселок городского типа Красный Бор',
#  'Гатчина',
#  'деревня Федоровское',
#  'Выборг',
#  'Кронштадт',
#  'Кировск',
#  'деревня Новое Девяткино',
#  'поселок Металлострой',
#  'поселок городского типа Лебяжье',
#  'поселок городского типа Сиверский',
#  'поселок Молодцово',
#  'поселок городского типа Кузьмоловский',
#  'садовое товарищество Новая Ропша',
#  'Павловск',
#  'деревня Пикколово',
#  'Всеволожск',
#  'Волхов',
#  'Кингисепп',
#  'Приозерск',
#  'Сестрорецк',
#  'деревня Куттузи',
#  'поселок Аннино',
#  'поселок городского типа Ефимовский',
#  'поселок Плодовое',
#  'деревня Заклинье',
#  'поселок Торковичи',
#  'поселок Первомайское',
#  'Красное Село',
#  'поселок Понтонный',
#  'Сясьстрой',
#  'деревня Старая',
#  'деревня Лесколово',
#  'поселок Новый Свет',
#  'Сланцы',
#  'село Путилово',
#  'Ивангород',
#  'Мурино',
#  'Шлиссельбург',
#  'Никольское',
#  'Зеленогорск',
#  'Сосновый Бор',
#  'деревня Оржицы',
#  'деревня Кальтино',
#  'Кудрово',
#  'поселок Романовка',
#  'поселок Бугры',
#  'поселок городского типа Рощино',
#  'Кириши',
#  'Луга',
#  'Волосово',
#  'Отрадное',
#  'село Павлово',
#  'поселок Оредеж',
#  'село Копорье',
#  'поселок Молодежное',
#  'Тихвин',
#  'поселок Победа',
#  'деревня Нурма',
#  'поселок городского типа Синявино',
#  'Тосно',
#  'поселок Стрельна',
#  'Бокситогорск',
#  'поселок Александровская',
#  'деревня Лопухинка',
#  'Пикалево',
#  'поселок Терволово',
#  'поселок городского типа Советский',
#  'Подпорожье',
#  'поселок Петровское',
#  'поселок городского типа Токсово',
#  'поселок Сельцо',
#  'поселок городского типа Вырица',
#  'деревня Кипень',
#  'деревня Келози',
#  'деревня Вартемяги',
#  'поселок Тельмана',
#  'поселок Севастьяново',
#  'городской поселок Большая Ижора',
#  'городской поселок Павлово',
#  'деревня Агалатово',
#  'поселок Новогорелово',
#  'городской поселок Лесогорский',
#  'деревня Лаголово',
#  'поселок Цвелодубово',
#  'поселок городского типа Рахья',
#  'деревня Белогорка',
#  'поселок Заводской',
#  'городской поселок Новоселье',
#  'деревня Большие Колпаны',
#  'деревня Горбунки',
#  'деревня Батово',
#  'деревня Заневка',
#  'деревня Иссад',
#  'Приморск',
#  'городской поселок Федоровское',
#  'деревня Мистолово',
#  'Новая Ладога',
#  'поселок Зимитицы',
#  'поселок Барышево',
#  'деревня Разметелево',
#  'поселок городского типа имени Свердлова',
#  'деревня Пеники',
#  'поселок Рябово',
#  'деревня Пудомяги',
#  'поселок станции Корнево',
#  'деревня Низино',
#  'деревня Бегуницы',
#  'поселок Поляны',
#  'городской поселок Мга',
#  'поселок Елизаветино',
#  'поселок городского типа Кузнечное',
#  'деревня Колтуши',
#  'поселок Запорожское',
#  'деревня Гостилицы',
#  'деревня Малое Карлино',
#  'поселок Мичуринское',
#  'поселок городского типа имени Морозова',
#  'поселок Песочный',
#  'поселок Сосново',
#  'деревня Аро',
#  'поселок Ильичево',
#  'поселок городского типа Тайцы',
#  'деревня Малое Верево',
#  'деревня Извара',
#  'поселок станции Вещево',
#  'село Паша',
#  'деревня Калитино',
#  'поселок городского типа Ульяновка',
#  'деревня Чудской Бор',
#  'поселок городского типа Дубровка',
#  'деревня Мины',
#  'поселок Войсковицы',
#  'деревня Коркино',
#  'поселок Ропша',
#  'поселок городского типа Приладожский',
#  'поселок Щеглово',
#  'поселок Гаврилово',
#  'Лодейное Поле',
#  'деревня Рабитицы',
#  'поселок городского типа Никольский',
#  'деревня Кузьмолово',
#  'деревня Малые Колпаны',
#  'поселок Петро-Славянка',
#  'городской поселок Назия',
#  'поселок Репино',
#  'поселок Углово',
#  'поселок Старая Малукса',
#  'садовое товарищество Рахья',
#  'деревня Меньково',
#  'деревня Старые Бегуницы',
#  'поселок Саперный',
#  'поселок Семрино',
#  'поселок Глажево',
#  'поселок Кобринское',
#  'деревня Гарболово',
#  'деревня Юкки',
#  'поселок станции Приветнинское',
#  'деревня Мануйлово',
#  'деревня Пчева',
#  'поселок Цвылево',
#  'поселок Мельниково',
#  'поселок Пудость',
#  'поселок Усть-Луга',
#  'Светогорск',
#  'Любань',
#  'поселок Селезнево',
#  'поселок городского типа Рябово',
#  'Каменногорск',
#  'деревня Кривко',
#  'поселок Глебычево',
#  'деревня Парицы',
#  'поселок Жилпоселок',
#  'поселок городского типа Мга',
#  'поселок Войскорово',
#  'село Никольское',
#  'поселок Стеклянный',
#  'поселок городского типа Важины',
#  'поселок Мыза-Ивановка',
#  'село Русско-Высоцкое',
#  'поселок городского типа Форносово',
#  'село Старая Ладога',
#  'поселок Житково',
#  'городской поселок Виллози',
#  'деревня Лампово',
#  'деревня Шпаньково',
#  'деревня Лаврики',
#  'поселок Сумино',
#  'поселок Возрождение',
#  'деревня Старосиверская',
#  'поселок Кикерино',
#  'деревня Старое Хинколово',
#  'поселок Пригородный',
#  'поселок Торфяное',
#  'городской поселок Будогощь',
#  'поселок Суходолье',
#  'поселок Красная Долина',
#  'деревня Хапо-Ое',
#  'поселок городского типа Дружная Горка',
#  'поселок Лисий Нос',
#  'деревня Яльгелево',
#  'село Рождествено',
#  'деревня Старополье',
#  'поселок Левашово',
#  'деревня Сяськелево',
#  'деревня Камышовка',
#  'садоводческое некоммерческое товарищество Лесная Поляна',
#  'деревня Хязельки',
#  'поселок Жилгородок',
#  'поселок городского типа Павлово',
#  'деревня Ялгино',
#  'поселок Новый Учхоз',
#  'городской поселок Рощино',
#  'поселок Гончарово',
#  'поселок Почап',
#  'поселок Саперное',
#  'поселок Платформа 69-й километр',
#  'поселок Каложицы',
#  'деревня Фалилеево',
#  'деревня Пельгора',
#  'поселок городского типа Лесогорский',
#  'деревня Торошковичи',
#  'поселок Белоостров',
#  'поселок Алексеевка',
#  'поселок Серебрянский',
#  'поселок Лукаши',
#  'деревня Щеглово',
#  'деревня Тарасово',
#  'поселок Кингисеппский',
#  'поселок при железнодорожной станции Вещево',
#  'поселок Ушаки',
#  'деревня Котлы',
#  'деревня Сижно',
#  'деревня Торосово',
#  'поселок Форт Красная Горка',
#  'деревня Новолисино',
#  'поселок станции Громово',
#  'деревня Глинка',
#  'поселок городского типа Назия',
#  'деревня Старая Пустошь',
#  'поселок Коммунары',
#  'поселок Починок',
#  'поселок городского типа Вознесенье',
#  'деревня Разбегаево',
#  'поселок Гладкое',
#  'поселок при железнодорожной станции Приветнинское',
#  'поселок Тесово-4',
#  'деревня Бор',
#  'поселок Коробицыно',
#  'деревня Большая Вруда',
#  'деревня Курковицы',
#  'городской поселок Советский',
#  'поселок Кобралово',
#  'деревня Суоранда',
#  'поселок городского типа Кондратьево',
#  'коттеджный поселок Счастье',
#  'поселок Любань',
#  'деревня Реброво',
#  'деревня Зимитицы',
#  'деревня Тойворово',
#  'поселок Семиозерье',
#  'поселок Лесное',
#  'поселок Совхозный',
#  'поселок Ленинское',
#  'поселок Суйда',
#  'деревня Нижние Осельки',
#  'поселок станции Свирь',
#  'поселок Перово',
#  'Высоцк',
#  'поселок Гарболово',
#  'село Шум',
#  'поселок Котельский',
#  'поселок станции Лужайка',
#  'деревня Большая Пустомержа',
#  'поселок Красносельское',
#  'деревня Вахнова Кара',
#  'деревня Пижма',
#  'коттеджный поселок Кивеннапа Север',
#  'поселок Ромашки',
#  'деревня Каськово',
#  'деревня Куровицы',
#  'поселок Плоское',
#  'поселок городского типа Большая Ижора',
#  'поселок Кирпичное',
#  'деревня Ям-Тесово',
#  'деревня Раздолье',
#  'деревня Терпилицы',
#  'поселок Шугозеро',
#  'деревня Ваганово',
#  'поселок Пушное',
#  'садовое товарищество Садко',
#  'поселок Усть-Ижора',
#  'деревня Выскатка',
#  'городской поселок Свирьстрой',
#  'поселок Громово',
#  'деревня Кисельня',
#  'деревня Трубников Бор',
#  'поселок Калитино',
#  'поселок Высокоключевой',
#  'садовое товарищество Приладожский',
#  'поселок Пансионат Зеленый Бор',
#  'деревня Ненимяки',
#  'деревня Снегиревка',
#  'деревня Рапполово',
#  'деревня Пустынка',
#  'поселок Рабитицы',
#  'деревня Большой Сабск',
#  'деревня Русско',
#  'деревня Лупполово',
#  'деревня Большое Рейзино',
#  'деревня Малая Романовка',
#  'поселок Дружноселье',
#  'поселок Пчевжа',
#  'поселок Володарское',
#  'деревня Нижняя',
#  'коттеджный поселок Лесное',
#  'деревня Тихковицы',
#  'деревня Борисова Грива',
#  'поселок Дзержинского']

# %%
len(data['locality_name'].unique().tolist())
# Out:
# 330

# %% [markdown]
# 9. Незаполненные данные в столбце airports_nearest

# %% [markdown]
# Оставим эти данные незаполненными, т.к. у нас нет технической возможности определить это расстояние (например, с помощью сервиса карт, у нас нет адреса продаваемой недвижимости в Санкт-Петербурге), а по отдалению квартиры от центра это определить невозможно, т.к. аэропорт находится на южном краю города на расстоянии около 18 км от центра.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Да, есть такое
# </div>

# %% [markdown]
# 10. Незаполненные данные в столбце cityCenters_nearest (расстояние до центра города).

# %%
data['cityCenters_nearest'].isna().sum()
# Out:
# 5519

# %%
max_min_description('cityCenters_nearest')
# Out:
# Столбец: cityCenters_nearest
# Минимум 181.0
# Медиана 13098.5
# Среднее 14191.277832783278
# Максимум 65968.0

# %% [markdown]
# Посмотрим, какое среднее расстояние до центра С-Петербурга указано для этих населенных пунктов в таблице.

# %%
data_cityCenters_nearest_pivot=data.pivot_table(index='locality_name', values='cityCenters_nearest', aggfunc='median')
data_cityCenters_nearest_pivot
# Out:
#                          cityCenters_nearest
# locality_name
# Зеленогорск                         53381.00
# Колпино                             32018.00
# Красное Село                        29140.50
# Кронштадт                           49575.00
# Ломоносов                           51677.00
# Павловск                            32683.00
# Петергоф                            33771.00
# Пушкин                              27930.50
# Санкт-Петербург                     12243.00
# Сестрорецк                          34821.00
# поселок Александровская             27468.00
# поселок Белоостров                  38868.00
# поселок Левашово                    25727.00
# поселок Лисий Нос                   28226.00
# поселок Металлострой                27602.00
# поселок Молодежное                  65764.00
# поселок Мурино                      21888.00
# поселок Парголово                   19311.00
# поселок Песочный                    26099.50
# поселок Петро-Славянка              27165.00
# поселок Понтонный                   32354.00
# поселок Репино                      42896.50
# поселок Саперный                    35859.50
# поселок Стрельна                    23506.00
# поселок Усть-Ижора                  28222.50
# поселок Шушары                      24212.00
# поселок Щеглово                     34085.00

# %% [markdown]
# Это соответствует действительности. А для других населенных пунктов, очевидно, это значение не заполнено. Если бы мы изучали влияние на цену квадратного метра расстояния до центра Санкт-Петербурга от населенных пунктов Ленинградской области, то мы бы попросили выгрузить эти данные из Яндекс-Карт :) или создали такую таблицу вручную, с точностью до нескольких километров, используя карты и линейку. В данном случае это трудоемко, и во второй части исследования мы рассматриваем только влияние этого расстояния на цену недвижимости, расположенную в Санкт-Петербурге, поэтому оставим эти значения пустыми и проверим только Санкт-Петербург.

# %%
spb_locality_data=data.query('locality_name=="Санкт-Петербург"')
spb_locality_data['cityCenters_nearest'].isna().sum()
# Out:
# 69

# %% [markdown]
# Итак, среди 15770 объявлений для Санкт-Петербурга расстояние не заполнено для 69 объявлений. Заполним вручную эти пропуски медианным значением.

# %%
data.loc[data['locality_name']=='Санкт-Петербург', 'cityCenters_nearest']=data.loc[data['locality_name']=='Санкт-Петербург','cityCenters_nearest'].fillna(data.loc[data['locality_name']=='Санкт-Петербург', 'cityCenters_nearest'].median())

# %%
spb_locality_data=data.query('locality_name=="Санкт-Петербург"')
spb_locality_data['cityCenters_nearest'].isna().sum()
# Out:
# 0

# %% [markdown]
# 11. Незаполненные данные в столбце parks_around3000

# %%
data['parks_around3000'].isna().sum()
# Out:
# 5518

# %%
data['parks_around3000'].value_counts()
# Out:
# 0.0    10106
# 1.0     5681
# 2.0     1747
# 3.0      647
# Name: parks_around3000, dtype: int64

# %% [markdown]
# Вероятно, что если данные в этом столбце не заполнены, парков на расстояниее 3 км нет. Поэтому заменим пропуски на 0.

# %%
data['parks_around3000']=data['parks_around3000'].fillna(0)
data['parks_around3000'].isna().sum()
# Out:
# 0

# %%
data['parks_around3000']=pd.to_numeric(data['parks_around3000'])
data['parks_around3000'].value_counts()
# Out:
# 0.00    15624
# 1.00     5681
# 2.00     1747
# 3.00      647
# Name: parks_around3000, dtype: int64

# %% [markdown]
# 12. Незаполненные данные в столбце parks_nearest

# %% [markdown]
# Оставим эти данные незаполненными, т.к. у нас нет технической возможности определить это расстояние (например, с помощью сервиса карт, у нас нет адреса продаваемой недвижимости).

# %% [markdown]
# 13. Незаполненные данные в столбце ponds_around3000. Поступим в точности как со столбцом parks_around3000.

# %%
data['ponds_around3000'].isna().sum()
# Out:
# 5518

# %%
data['ponds_around3000']=data['ponds_around3000'].fillna(0)
data['ponds_around3000'].isna().sum()
# Out:
# 0

# %%
data['ponds_around3000']=pd.to_numeric(data['ponds_around3000'])
data['ponds_around3000'].value_counts()
# Out:
# 0.00    14589
# 1.00     5717
# 2.00     1892
# 3.00     1501
# Name: ponds_around3000, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 24 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          23699 non-null float64
# floors_total            23699 non-null float64
# living_area             23699 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            23699 non-null float64
# balcony                 23699 non-null float64
# locality_name           23699 non-null object
# airports_nearest        18157 non-null object
# cityCenters_nearest     18249 non-null float64
# parks_around3000        23699 non-null float64
# parks_nearest           8079 non-null object
# ponds_around3000        23699 non-null float64
# ponds_nearest           9110 non-null object
# days_exposition         20518 non-null object
# living_area_ratio       21796 non-null float64
# kitchen_area_ratio      21421 non-null float64
# dtypes: bool(3), float64(12), int64(3), object(6)
# memory usage: 3.9+ MB

# %% [markdown]
# 14. Незаполненные данные в столбце ponds_nearest

# %% [markdown]
# Оставим эти данные незаполненными, т.к. у нас нет технической возможности определить это расстояние (например, с помощью сервиса карт, у нас нет адреса продаваемой недвижимости).

# %% [markdown]
# 15. Незаполненные данные в столбце days_exposition

# %%
data['days_exposition'].isna().sum()
# Out:
# 3181

# %%
data['days_exposition']=pd.to_numeric(data['days_exposition'])
max_min_description('days_exposition')
# Out:
# Столбец: days_exposition
# Минимум 1.0
# Медиана 95.0
# Среднее 180.88863436982163
# Максимум 1580.0

# %% [markdown]
# Поскольку в дальнейшем мы будем изучать длительность продажи отдельно, оставим эти данные незаполненными.

# %% [markdown]
# 16. Посмотрим на данные о числе комнат:

# %%
max_min_description('rooms')
# Out:
# Столбец: rooms
# Минимум 0
# Медиана 2.0
# Среднее 2.070635891809781
# Максимум 19

# %% [markdown]
# 17. Данные о студии и открытой планировке:

# %%
data['studio'].value_counts()
# Out:
# False    23550
# True       149
# Name: studio, dtype: int64

# %%
data['open_plan'].value_counts()
# Out:
# False    23632
# True        67
# Name: open_plan, dtype: int64

# %% [markdown]
# ### Типы данных

# %% [markdown]
# Кое-где мы уже изменили типы данных, пока заполняли пропущенные ячейки. Посмотрим, что осталось.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 24 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          23699 non-null float64
# floors_total            23699 non-null float64
# living_area             23699 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            23699 non-null float64
# balcony                 23699 non-null float64
# locality_name           23699 non-null object
# airports_nearest        18157 non-null object
# cityCenters_nearest     18249 non-null float64
# parks_around3000        23699 non-null float64
# parks_nearest           8079 non-null object
# ponds_around3000        23699 non-null float64
# ponds_nearest           9110 non-null object
# days_exposition         20518 non-null float64
# living_area_ratio       21796 non-null float64
# kitchen_area_ratio      21421 non-null float64
# dtypes: bool(3), float64(13), int64(3), object(5)
# memory usage: 3.9+ MB

# %% [markdown]
# 1. Для first_day_exposition формат данных строка. Превратим его в дату и посмотрим диапазон дат.

# %%
data['first_day_exposition']=pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%d')

# %%
print('Самая ранняя дата публикации', data['first_day_exposition'].min())
# Out:
# Самая ранняя дата публикации 2014-11-27 00:00:00

# %%
print('Самая поздняя дата публикации', data['first_day_exposition'].max())
# Out:
# Самая поздняя дата публикации 2019-05-03 00:00:00

# %% [markdown]
# 2. Исправим формат данных для airports_nearest, cityCenters_nearest, parks_nearest, ponds_nearest со строки на число, т.к. это расстояние в метрах. Оставим float, т.к. там есть пропуски в данных (NaN).

# %%
data['airports_nearest']=pd.to_numeric(data['airports_nearest'])
data['cityCenters_nearest']=pd.to_numeric(data['cityCenters_nearest'])
data['parks_nearest']=pd.to_numeric(data['parks_nearest'])
data['ponds_nearest']=pd.to_numeric(data['ponds_nearest'])

# %% [markdown]
# 3. Исправим формат данных для balcony, floors_total, parks_around3000, ponds_around3000 на int, т.к. все это целые числа.

# %%
data['balcony']=data['balcony'].astype('int')
data['floors_total']=data['floors_total'].astype('int')
data['parks_around3000']=data['parks_around3000'].astype('int')
data['ponds_around3000']=data['ponds_around3000'].astype('int')

# %% [markdown]
# 4. Формат данных days_exposition - строка. Превратим в numeric (float), ведь есть пропущенные данные (NaN).

# %%
data['days_exposition']=pd.to_numeric(data['days_exposition'])

# %%
max_min_description('days_exposition')
# Out:
# Столбец: days_exposition
# Минимум 1.0
# Медиана 95.0
# Среднее 180.88863436982163
# Максимум 1580.0

# %% [markdown]
# Проверим результат.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 24 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null datetime64[ns]
# rooms                   23699 non-null int64
# ceiling_height          23699 non-null float64
# floors_total            23699 non-null int64
# living_area             23699 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            23699 non-null float64
# balcony                 23699 non-null int64
# locality_name           23699 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18249 non-null float64
# parks_around3000        23699 non-null int64
# parks_nearest           8079 non-null float64
# ponds_around3000        23699 non-null int64
# ponds_nearest           9110 non-null float64
# days_exposition         20518 non-null float64
# living_area_ratio       21796 non-null float64
# kitchen_area_ratio      21421 non-null float64
# dtypes: bool(3), datetime64[ns](1), float64(12), int64(7), object(1)
# memory usage: 3.9+ MB

# %% [markdown]
# Данные приведены к желаемому формату, пропуски в данных оставлены только там, где правильнее оставить пустые значения как они есть.

# %% [markdown]
# ### Дубликаты

# %% [markdown]
# Проверим дубликаты строк в data.

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Дубликаты в датафрейме data отсутствуют.

# %% [markdown]
# ### Вывод

# %% [markdown]
# Мы заполнили пропуски или оставили пропущенные данные без изменения - там, где это уместно, изменили тип данных и проверили отсутствие дубликатов строк.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# 👍
# </div>

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# ### Цена квадратного метра

# %% [markdown]
# Добавим в таблицу цену квадратного метра и посмотрим общую информацию об этом столбце.

# %%
data['square_meter_price']=(data['last_price']) / (data['total_area'])

# %%
max_min_description('square_meter_price')
# Out:
# Столбец: square_meter_price
# Минимум 111.8348623853211
# Медиана 95000.0
# Среднее 99421.65639461846
# Максимум 1907500.0

# %% [markdown]
# Общая информация здесь малоинформативна, т.к. средняя цена квадратного метра явно зависит от множества факторов, и соответственно, при группировке данных по разным признакам будет различной. Это мы изучим далее.

# %% [markdown]
# ### День недели, месяц, год публикации объявления

# %% [markdown]
# Добавим в таблицу день недели, месяц и год публикации объявления

# %%
data['weekday_exposition'] = data['first_day_exposition'].dt.weekday
data['month_exposition'] = pd.DatetimeIndex(data['first_day_exposition']).month
data['year_exposition'] = pd.DatetimeIndex(data ['first_day_exposition']).year

# %%
data['weekday_exposition'].value_counts()
# Out:
# 3    4295
# 1    4183
# 4    4000
# 2    3974
# 0    3612
# 5    1936
# 6    1699
# Name: weekday_exposition, dtype: int64

# %%
data['month_exposition'].value_counts()
# Out:
# 2     2640
# 3     2587
# 4     2379
# 11    2371
# 10    2127
# 9     1981
# 6     1760
# 8     1744
# 7     1695
# 12    1641
# 1     1500
# 5     1274
# Name: month_exposition, dtype: int64

# %% [markdown]
# Весной и осенью размещается больше объявлений, летом, перед и после нового года - меньше.

# %%
data['year_exposition'].value_counts()
# Out:
# 2018    8519
# 2017    8190
# 2019    2879
# 2016    2783
# 2015    1191
# 2014     137
# Name: year_exposition, dtype: int64

# %% [markdown]
# Данные представлены с 2014 по 2019 г., ранее мы узнали, что с ноября 2014 по май 2019 г., в рамках полных лет: с 2015 по 2018 количество поданных объявлений в год постоянно растет.

# %% [markdown]
# ### Этаж: категория

# %% [markdown]
# Добавим в таблицу категорию этажа квартиры (варианты — первый, последний, другой)

# %%
max_min_description('floor')
# Out:
# Столбец: floor
# Минимум 1
# Медиана 4.0
# Среднее 5.892358327355584
# Максимум 33

# %% [markdown]
# Распределение по этажам (с номерами этажей):

# %%
data['floor'].value_counts()
# Out:
# 2     3368
# 3     3073
# 1     2917
# 4     2804
# 5     2621
# 6     1305
# 7     1218
# 8     1083
# 9     1051
# 10     687
# 12     526
# 11     523
# 13     379
# 15     343
# 14     337
# 16     315
# 17     227
# 18     178
# 19     147
# 21     125
# 22     113
# 20     110
# 23     100
# 24      63
# 25      46
# 26      24
# 27      10
# 28       1
# 33       1
# 29       1
# 30       1
# 32       1
# 31       1
# Name: floor, dtype: int64

# %% [markdown]
# Большинство квартир не выше 9-го этажа, квартир выше 26-го этажа - единицы.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Да, не самый высотный город :)
# </div>

# %%
def floor_description(row): 
    if row['floors_total']==row['floor']: 
        return 'последний этаж'
    if row['floor']==1: 
        return 'первый этаж'
    return 'другой этаж'

data['floor_category']=data.apply(floor_description, axis=1)

# %%
data['floor_category'].value_counts()
# Out:
# другой этаж       17441
# последний этаж     3366
# первый этаж        2892
# Name: floor_category, dtype: int64

# %% [markdown]
# Для того, чтобы в дальнейшем обрабатывать это разделение на категории этажей, добавим идентификатор категории (числовой): 1 - для первого этажа, 2 - для "другого" этажа и 3 - для последнего.

# %%
def floor_category_identify(row): 
    if row['floor_category']=='последний этаж': 
        return 3
    if row['floor_category']=='первый этаж': 
        return 1
    return 2

data['floor_category_id']=data.apply(floor_category_identify, axis=1)

# %% [markdown]
# ### Соотношение площадей

# %% [markdown]
# Соотношение жилой и общей площади рассчитывалось нами ранее и содержалось в столбце living_area_ratio. Там были пропуски из-за пропусков данных. Теперь эти пропуски заменены, и мы заменим данные в столбце новыми.

# %%
data['living_area_ratio']=(data['living_area'])/(data['total_area'])

# %%
max_min_description('living_area_ratio')
# Out:
# Столбец: living_area_ratio
# Минимум 0.02158273381294964
# Медиана 0.5678598992678503
# Среднее 0.5650139963401482
# Максимум 1.0

# %% [markdown]
# Аналогично столбец kitchen_area_ratio.

# %%
data['kitchen_area_ratio']=(data['kitchen_area'])/(data['total_area'])

# %%
max_min_description('kitchen_area_ratio')
# Out:
# Столбец: kitchen_area_ratio
# Минимум 0.025380710659898477
# Медиана 0.1724137931034483
# Среднее 0.18591858221524582
# Максимум 0.7878787878787878

# %% [markdown]
# Посмотрим результат:

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20 13000000.00      108.00           2019-03-07      3
# 1             7  3350000.00       40.40           2018-12-04      1
# 2            10  5196000.00       56.00           2015-08-20      2
# 3             0 64900000.00      159.00           2015-07-24      3
# 4             2 10000000.00      100.00           2018-06-19      2
# 5            10  2890000.00       30.40           2018-09-10      1
# 6             6  3700000.00       37.30           2017-11-02      1
# 7             5  7915000.00       71.60           2019-04-18      2
# 8            20  2900000.00       33.16           2018-05-23      1
# 9            18  5400000.00       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70            16        51.00      8         False   False
# 1            2.65            11        18.60      1         False   False
# 2            2.65             5        34.30      4         False   False
# 3            2.65            14        90.29      9         False   False
# 4            3.03            14        32.00     13         False   False
# 5            2.65            12        14.40      5         False   False
# 6            2.65            26        10.60      6         False   False
# 7            2.65            24        40.66     22         False   False
# 8            2.65            27        15.43     26         False   False
# 9            2.50             9        43.60      7         False   False
#
#    open_plan  kitchen_area  balcony              locality_name  \
# 0      False         25.00        0            Санкт-Петербург
# 1      False         11.00        2             поселок Шушары
# 2      False          8.30        0            Санкт-Петербург
# 3      False         27.41        0            Санкт-Петербург
# 4      False         41.00        0            Санкт-Петербург
# 5      False          9.10        0  городской поселок Янино-1
# 6      False         14.40        1          поселок Парголово
# 7      False         18.90        2            Санкт-Петербург
# 8      False          8.81        0             поселок Мурино
# 9      False          6.50        2            Санкт-Петербург
#
#    airports_nearest  cityCenters_nearest  parks_around3000  parks_nearest  \
# 0          18863.00             16028.00                 1         482.00
# 1          12817.00             18603.00                 0            nan
# 2          21741.00             13933.00                 1          90.00
# 3          28098.00              6800.00                 2          84.00
# 4          31856.00              8098.00                 2         112.00
# 5               nan                  nan                 0            nan
# 6          52996.00             19143.00                 0            nan
# 7          23982.00             11634.00                 0            nan
# 8               nan                  nan                 0            nan
# 9          50898.00             15008.00                 0            nan
#
#    ponds_around3000  ponds_nearest  days_exposition  living_area_ratio  \
# 0                 2         755.00              nan               0.47
# 1                 0            nan            81.00               0.46
# 2                 2         574.00           558.00               0.61
# 3                 3         234.00           424.00               0.57
# 4                 1          48.00           121.00               0.32
# 5                 0            nan            55.00               0.47
# 6                 0            nan           155.00               0.28
# 7                 0            nan              nan               0.57
# 8                 0            nan           189.00               0.47
# 9                 0            nan           289.00               0.71
#
#    kitchen_area_ratio  square_meter_price  weekday_exposition  \
# 0                0.23           120370.37                   3
# 1                0.27            82920.79                   1
# 2                0.15            92785.71                   3
# 3                0.17           408176.10                   4
# 4                0.41           100000.00                   1
# 5                0.30            95065.79                   0
# 6                0.39            99195.71                   3
# 7                0.26           110544.69                   3
# 8                0.27            87454.76                   2
# 9                0.11            88524.59                   6
#
#    month_exposition  year_exposition floor_category  floor_category_id
# 0                 3             2019    другой этаж                  2
# 1                12             2018    первый этаж                  1
# 2                 8             2015    другой этаж                  2
# 3                 7             2015    другой этаж                  2
# 4                 6             2018    другой этаж                  2
# 5                 9             2018    другой этаж                  2
# 6                11             2017    другой этаж                  2
# 7                 4             2019    другой этаж                  2
# 8                 5             2018    другой этаж                  2
# 9                 2             2017    другой этаж                  2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 30 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null datetime64[ns]
# rooms                   23699 non-null int64
# ceiling_height          23699 non-null float64
# floors_total            23699 non-null int64
# living_area             23699 non-null float64
# floor                   23699 non-null int64
# is_apartment            23699 non-null bool
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            23699 non-null float64
# balcony                 23699 non-null int64
# locality_name           23699 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18249 non-null float64
# parks_around3000        23699 non-null int64
# parks_nearest           8079 non-null float64
# ponds_around3000        23699 non-null int64
# ponds_nearest           9110 non-null float64
# days_exposition         20518 non-null float64
# living_area_ratio       23699 non-null float64
# kitchen_area_ratio      23699 non-null float64
# square_meter_price      23699 non-null float64
# weekday_exposition      23699 non-null int64
# month_exposition        23699 non-null int64
# year_exposition         23699 non-null int64
# floor_category          23699 non-null object
# floor_category_id       23699 non-null int64
# dtypes: bool(3), datetime64[ns](1), float64(13), int64(11), object(2)
# memory usage: 4.9+ MB

# %% [markdown]
# ## Исследовательский анализ данных

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Площадь, цена, число комнат, высота потолков.

# %% [markdown]
# 1. Площадь общая

# %%
data['total_area'].describe()
# Out:
# count   23699.00
# mean       60.35
# std        35.65
# min        12.00
# 25%        40.00
# 50%        52.00
# 75%        69.90
# max       900.00
# Name: total_area, dtype: float64

# %% [markdown]
# Средняя площадь квартир 52 кв м (медиана) / 60 кв м (среднее). Разброс данных велик: 35 кв м. Есть небольшие квартиры: 12 м. и очень большие - 900 кв. м.

# %%
data['total_area'].hist(bins=100, figsize=(15,8), grid=True)

# %% [markdown]
# Распределение похоже на распределение Пуассона, большинство данных лежит в пределеах от 0 до 200 м.

# %% [markdown]
# <div class="alert alert-warning">
# <h2>Комментарий ревьюера</h2>
#
# Мир распределений намного богаче, чем нормальное распределение и Пуассоновское, по графику кроме нормальности определить распределение на мой взгляд тяжело. Важно понимать, что описывает конкретное распределение. Например распределение Пуассона описывает поток случайных событый, а имеенно их число на временном интервале, поэтому странно считать Пуассоновским распределение площади, а вот число событий о продаже квартиры вполне. Также, время между продажами, например, имеет экспоненциальное рапределение.
# </div>

# %% [markdown]
# Посмотрим распределение площади в пределах от 12 до 200 метров.

# %%
data['total_area'].hist(bins=100, figsize=(12,8), grid=True, range=(12,200))

# %% [markdown]
# На определенных значениях есть пики и падения гистограммы, что связано, очевидно, с тем, что большинство квартир имеют стандартные планировки, поэтому квартир с площадью, например, 46 кв.м. может быть много, а 49 кв. м. - намного меньше, хотя площадь отличается ненамного.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарйи ревьюера</h2>
#
# Всё верно, пики это скорее всего однушки / двушки / трёшки с поправкой на балконы
# </div>

# %% [markdown]
# Квартир какой площади больше всего?

# %%
data_pivot_total_area=data.pivot_table(index='total_area', values='living_area', aggfunc='count')
data_pivot_total_area.sort_values(by='living_area', ascending=False).head(10)
# Out:
#             living_area
# total_area
# 45.00               419
# 42.00               383
# 60.00               347
# 31.00               346
# 44.00               345
# 40.00               315
# 43.00               301
# 32.00               289
# 46.00               282
# 36.00               280

# %% [markdown]
# 45, 42 и 60 квадратных метов общей площади

# %% [markdown]
# 2. Жилая площадь

# %%
data['living_area'].describe()
# Out:
# count   23699.00
# mean       34.58
# std        22.34
# min         2.00
# 25%        19.00
# 50%        30.00
# 75%        42.10
# max       409.70
# Name: living_area, dtype: float64

# %% [markdown]
# Средняя жилая площадь 30-34 кв м., от 2 до 410 кв м. Показатель жилой площади, порой, является техническим показателем (в документах) и не отражать фактическую полезную площадь квартиры (например, той, где есть большой коридор или кухня, используемая как гостиная или осуществлена перепланировка).

# %%
data['living_area'].hist(bins=100, figsize=(15,8))

# %% [markdown]
# Посмотрим, как распределяется жилая площадь в диапазоне от 2 до 100 м.

# %%
data['living_area'].hist(bins=100, figsize=(15,8), grid=True, range=(2,100))

# %%
data_pivot_living_area=data.pivot_table(index='living_area', values='total_area', aggfunc='count')
data_pivot_living_area.sort_values(by='total_area', ascending=False).head(10)
# Out:
#              total_area
# living_area
# 18.00               882
# 17.00               675
# 30.00               598
# 16.00               486
# 20.00               481
# 28.00               423
# 31.00               381
# 19.00               329
# 32.00               320
# 29.00               319

# %% [markdown]
# Очевидно, что разница в количества близлежащих квадратных метров связана также со стандартными планировками.

# %% [markdown]
# 3. Площадь кухни

# %%
data['kitchen_area'].describe()
# Out:
# count   23699.00
# mean       10.49
# std         6.03
# min         1.30
# 25%         7.00
# 50%         9.00
# 75%        12.00
# max       112.00
# Name: kitchen_area, dtype: float64

# %%
data['kitchen_area'].hist(bins=100, figsize=(10,6))

# %%
data_pivot_kitchen_area=data.pivot_table(index='kitchen_area', values='total_area', aggfunc='count')
data_pivot_kitchen_area.sort_values(by='total_area', ascending=False).head(10)
# Out:
#               total_area
# kitchen_area
# 6.00                1300
# 10.00               1283
# 8.00                1113
# 9.00                1101
# 7.00                1062
# 11.00                798
# 12.00                662
# 8.50                 415
# 5.50                 403
# 14.00                381

# %% [markdown]
# Самое большое количество кухонь - шестиметровые и десятиметровые - стандарт застроек спальных райнов СПб.

# %%
data['kitchen_area'].hist(bins=100, figsize=(15,8), grid=True, range=(0,20))

# %% [markdown]
# 4. Цена (общая)

# %%
data['last_price'].describe()
# Out:
# count       23699.00
# mean      6541548.77
# std      10887013.27
# min         12190.00
# 25%       3400000.00
# 50%       4650000.00
# 75%       6800000.00
# max     763000000.00
# Name: last_price, dtype: float64

# %% [markdown]
# Посмотрим на цену в тысячах рублей.

# %%
data['last_price_thousand']=(data['last_price']) / (1000)

# %%
data['last_price_thousand'].describe()
# Out:
# count    23699.00
# mean      6541.55
# std      10887.01
# min         12.19
# 25%       3400.00
# 50%       4650.00
# 75%       6800.00
# max     763000.00
# Name: last_price_thousand, dtype: float64

# %% [markdown]
# Квартиры от 12 тыс.рублей до 763 миллиона рублей. Посмотрим на минимальное и максимальное значение.

# %%
data.query('last_price_thousand==12.190000')
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 8793             7    12190.00      109.00           2019-03-20      2
#
#       ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 8793            2.75            25        32.00     25         False   False
#
#       open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 8793      False         40.50        0  Санкт-Петербург          36421.00
#
#       cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 8793              9176.00                 1         805.00                 0
#
#       ponds_nearest  days_exposition  living_area_ratio  kitchen_area_ratio  \
# 8793            nan             8.00               0.29                0.37
#
#       square_meter_price  weekday_exposition  month_exposition  \
# 8793              111.83                   2                 3
#
#       year_exposition  floor_category  floor_category_id  last_price_thousand
# 8793             2019  последний этаж                  3                12.19

# %%
data.query('last_price_thousand==763000.000000')
# Out:
#        total_images   last_price  total_area first_day_exposition  rooms  \
# 12971            19 763000000.00      400.00           2017-09-30      7
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 12971            2.65            10       250.00     10         False   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 12971      False         68.97        2  Санкт-Петербург          25108.00
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 12971              3956.00                 1         530.00                 3
#
#        ponds_nearest  days_exposition  living_area_ratio  kitchen_area_ratio  \
# 12971         756.00            33.00               0.62                0.17
#
#        square_meter_price  weekday_exposition  month_exposition  \
# 12971          1907500.00                   5                 9
#
#        year_exposition  floor_category  floor_category_id  last_price_thousand
# 12971             2017  последний этаж                  3            763000.00

# %% [markdown]
# Если квартира стоимостью 763 млн. рублей площадью 400 кв.метров в 4 км. еще очень похожа на правдивые данные, то квартира ценой 12 тыс. рублей имеет 109 квадратных метров и расположена в 25-этажном доме на последнем этаже в Санкт-Петербурге в 9 км.от центра и в 800 м. от парка, при этом ее жилая площадь всего 32 квадратных метра и продана она была в 2019 году. Если застройка с высотой 25 этажей на расстоянии 9 км от центра еще может быть разрешена (центр СПб застраивать высотными зданиями нельзя), то цена в 12 тыс.рублей явно некорректная, скорее это 12 миллионов рублей (из-за небольшой жилой площади?). Эта запись очень похожа на ошибочную. Поэтому потребуется исследовать квартиры с наименьшей и наибольшей ценой, сделав сводную таблицу.

# %%
data_pivot_last_price_thousand=data.pivot_table(index='last_price_thousand', values='total_area', aggfunc='count')
data_pivot_last_price_thousand.sort_values(by='total_area', ascending=False).head(10)
# Out:
#                      total_area
# last_price_thousand
# 4500.00                     342
# 3500.00                     291
# 4300.00                     260
# 4000.00                     260
# 4200.00                     259
# 3600.00                     257
# 3300.00                     244
# 3800.00                     240
# 3200.00                     238
# 3700.00                     234

# %% [markdown]
# Больше всего квартир по цене 4.5-3.2 млн.рублей

# %% [markdown]
# Отсортируем по цене, чтобы посмотреть максимальные и минимальные цены.

# %%
data_pivot_last_price_thousand=data.pivot_table(index='last_price_thousand', values='total_area', aggfunc='count')
data_pivot_last_price_thousand.sort_values(by='last_price_thousand', ascending=False).head(10)
# Out:
#                      total_area
# last_price_thousand
# 763000.00                     1
# 420000.00                     1
# 401300.00                     1
# 330000.00                     1
# 300000.00                     1
# 289238.40                     1
# 245000.00                     1
# 240000.00                     1
# 230000.00                     1
# 190870.00                     1

# %%
data_pivot_last_price_thousand.sort_values(by='last_price_thousand', ascending=False).tail(10)
# Out:
#                      total_area
# last_price_thousand
# 530.00                        1
# 520.00                        1
# 500.00                        4
# 490.00                        2
# 480.00                        1
# 470.00                        3
# 450.00                        4
# 440.00                        1
# 430.00                        2
# 12.19                         1

# %% [markdown]
# Видно, что цена в размере 12 тыс.рублей за квартиру - одно такое значение. Далее - от 430 тыс.рублей, что уже больше похоже на правдивые данные.

# %% [markdown]
# В дальнейшем мы более подробно рассмотрим редкие и выбивающиеся значения, в том числе для цены.

# %% [markdown]
# Посмотрим на гистограмму

# %%
data['last_price_thousand'].hist(bins=100, figsize=(10,8))

# %% [markdown]
# В диапазоне от 0 до 40 млн рублей:

# %%
data['last_price_thousand'].hist(bins=100, figsize=(8,6), range=(0,40000))

# %% [markdown]
# Диапазон от 0 до 20 млн

# %%
data['last_price_thousand'].hist(bins=100, figsize=(10,8), range=(0,20000))

# %% [markdown]
# Распределение похоже на распределение Пуассона, без явных пиков и падений, как в случае с площадью квартиры, т.к. цена зависит от множества факторов и не подвержена ограничениям типовых планировок, как площадь.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Тут тоже надо аккуратно с распределениями
# </div>

# %% [markdown]
# 5. Цена за квадратный метр

# %%
data['square_meter_price'].describe().astype('int')
# Out:
# count      23699
# mean       99421
# std        50306
# min          111
# 25%        76585
# 50%        95000
# 75%       114256
# max      1907500
# Name: square_meter_price, dtype: int64

# %%
data['square_meter_price'].hist(bins=100, figsize=(15,8))

# %% [markdown]
# Посмотрим диапазон от 0 до 250 тысяч.

# %%
data['square_meter_price'].hist(bins=100, figsize=(15,8), range=(0, 250_000))

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Это уже нормальное (что неудивительно)
# </div>

# %% [markdown]
# 6. Число комнат

# %%
data['rooms'].describe()
# Out:
# count   23699.00
# mean        2.07
# std         1.08
# min         0.00
# 25%         1.00
# 50%         2.00
# 75%         3.00
# max        19.00
# Name: rooms, dtype: float64

# %% [markdown]
# От 0 до 19 комнат, среднее количество комнат: 2

# %%
data['rooms'].hist(bins=100, figsize=(15,8))

# %% [markdown]
# 7. Высота потолков

# %%
data['ceiling_height'].describe()
# Out:
# count   23699.00
# mean        2.72
# std         0.99
# min         1.00
# 25%         2.60
# 50%         2.65
# 75%         2.70
# max       100.00
# Name: ceiling_height, dtype: float64

# %%
data['ceiling_height'].hist(bins=100, figsize=(15,8))

# %% [markdown]
# 2.65 - стандарт высоты потолков.

# %% [markdown]
# Высоту потолка в 100 метров рассмотрим, рассматривая редкие и выбивающиеся значения.

# %% [markdown]
# ### Время продажи квартиры

# %% [markdown]
# Изучим время продажи квартиры. Построим гистограмму. Посчитаем среднее и медиану. Опишем, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
data['days_exposition'].describe()
# Out:
# count   20518.00
# mean      180.89
# std       219.73
# min         1.00
# 25%        45.00
# 50%        95.00
# 75%       232.00
# max      1580.00
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'].hist(bins=100, figsize=(10,5))

# %% [markdown]
# Посмотрим диапазон от 0 до 365 дней.

# %%
data['days_exposition'].hist(bins=100, figsize=(10,5), range=(0,365))

# %% [markdown]
# Есть некоторое количество выдающихся значений около 50 дней, 60 дней и т.д. Посмотрим распределение по сводной таблице.

# %%
data_pivot_days_exposition=data.pivot_table(index='days_exposition', values='total_area', aggfunc='count')
data_pivot_days_exposition.sort_values(by='total_area', ascending=False).head(10)
# Out:
#                  total_area
# days_exposition
# 45.00                   880
# 60.00                   538
# 7.00                    234
# 30.00                   208
# 90.00                   204
# 4.00                    176
# 3.00                    158
# 5.00                    152
# 14.00                   148
# 9.00                    143

# %% [markdown]
# Наибольшее количество квартир продалось за 45 дней, 60 дней, 7, 30 и 90. Возможно, это периоды, на которые можно оплатить размещение объявления на сервисе или время, по истечении которого объявление снимается автоматически?

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Интересная догадка, вполне может быть
# </div>

# %%
data_pivot_days_exposition=data.pivot_table(index='days_exposition', values='total_area', aggfunc='count')
data_pivot_days_exposition.sort_values(by='days_exposition', ascending=True).head(10)
# Out:
#                  total_area
# days_exposition
# 1.00                      1
# 2.00                      3
# 3.00                    158
# 4.00                    176
# 5.00                    152
# 6.00                    124
# 7.00                    234
# 8.00                    139
# 9.00                    143
# 10.00                   127

# %% [markdown]
# Что касается скорости продажи 1-2 дня, то за этот период продаются единицы квартир. Остальные - за срок хотя бы от 3 дней.

# %% [markdown]
# Итак, посмотрим объявления со временем продажи более 3 лет.

# %%
data_long_sales=data.query('days_exposition>1095').copy()
data_long_sales
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 353               4  5990000.00       43.50           2015-05-08      1
# 398               7 12789000.00       79.30           2014-12-09      2
# 437              12  3350000.00       37.00           2015-02-24      1
# 459              13  5200000.00       51.00           2016-03-02      2
# 512               8  6260000.00       43.30           2014-12-09      1
# ...             ...         ...         ...                  ...    ...
# 23055             8  3200000.00       33.00           2016-03-18      1
# 23212             9  7515162.00       58.80           2015-03-10      2
# 23248             5  4900000.00       80.00           2014-12-25      3
# 23318             6  5620020.00       82.30           2015-03-10      3
# 23426            17  8778000.00       47.50           2014-12-29      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 353              3.00             5        25.00      4         False   False
# 398              3.00             8        43.10      5         False   False
# 437              2.55             6        17.80      6         False   False
# 459              2.55             9        32.00      5         False   False
# 512              2.65             8        24.59      5         False   False
# ...               ...           ...          ...    ...           ...     ...
# 23055            2.65            24        13.05      3         False   False
# 23212            2.65            10        30.40      3         False   False
# 23248            2.65            15        47.00     14         False   False
# 23318            2.70            21        45.60     12         False   False
# 23426            3.00             7        26.97      4         False   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 353        False          9.40        0  Санкт-Петербург          10527.00
# 398        False         17.60        0  Санкт-Петербург          39393.00
# 437        False          8.40        0         Петергоф          46151.00
# 459        False          6.00        0  Санкт-Петербург          48522.00
# 512        False          7.47        0  Санкт-Петербург          39946.00
# ...          ...           ...      ...              ...               ...
# 23055      False          9.75        0   поселок Шушары          13461.00
# 23212      False         11.10        0  Санкт-Петербург          23604.00
# 23248      False          9.00        2   поселок Мурино               nan
# 23318      False         15.70        0  Санкт-Петербург          21793.00
# 23426      False         11.70        2  Санкт-Петербург          39412.00
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 353               10278.00                 1          93.00                 0
# 398               11096.00                 1         537.00                 0
# 437               34044.00                 1         185.00                 1
# 459               16360.00                 0            nan                 0
# 512               10720.00                 1        2102.00                 3
# ...                    ...               ...            ...               ...
# 23055             19247.00                 0            nan                 1
# 23212              5294.00                 0            nan                 1
# 23248                  nan                 0            nan                 0
# 23318             17121.00                 0            nan                 1
# 23426             10186.00                 1        1424.00                 3
#
#        ponds_nearest  days_exposition  living_area_ratio  kitchen_area_ratio  \
# 353              nan          1292.00               0.57                0.22
# 398              nan          1345.00               0.54                0.22
# 437           755.00          1273.00               0.48                0.23
# 459              nan          1153.00               0.63                0.12
# 512           303.00          1155.00               0.57                0.17
# ...              ...              ...                ...                 ...
# 23055         351.00          1130.00               0.40                0.30
# 23212         434.00          1239.00               0.52                0.19
# 23248            nan          1187.00               0.59                0.11
# 23318          31.00          1200.00               0.55                0.19
# 23426         204.00          1360.00               0.57                0.25
#
#        square_meter_price  weekday_exposition  month_exposition  \
# 353             137701.15                   4                 5
# 398             161273.64                   1                12
# 437              90540.54                   1                 2
# 459             101960.78                   2                 3
# 512             144572.75                   1                12
# ...                   ...                 ...               ...
# 23055            96969.70                   4                 3
# 23212           127808.88                   1                 3
# 23248            61250.00                   3                12
# 23318            68287.00                   1                 3
# 23426           184800.00                   0                12
#
#        year_exposition  floor_category  floor_category_id  last_price_thousand
# 353               2015     другой этаж                  2              5990.00
# 398               2014     другой этаж                  2             12789.00
# 437               2015  последний этаж                  3              3350.00
# 459               2016     другой этаж                  2              5200.00
# 512               2014     другой этаж                  2              6260.00
# ...                ...             ...                ...                  ...
# 23055             2016     другой этаж                  2              3200.00
# 23212             2015     другой этаж                  2              7515.16
# 23248             2014     другой этаж                  2              4900.00
# 23318             2015     другой этаж                  2              5620.02
# 23426             2014     другой этаж                  2              8778.00
#
# [166 rows x 31 columns]

# %%
data_long_sales['days_exposition'].describe()
# Out:
# count    166.00
# mean    1247.43
# std      117.16
# min     1099.00
# 25%     1154.25
# 50%     1213.50
# 75%     1330.25
# max     1580.00
# Name: days_exposition, dtype: float64

# %% [markdown]
# 166 квартир продавались очень долго.

# %% [markdown]
# Посмотрим на общую цену квартиры.

# %%
data_long_sales['last_price'].mean()
# Out:
# 9223560.61445783

# %% [markdown]
# Посмотрим на среднюю цену квадратного метра для этих долго продающихся квартир.

# %%
data_long_sales['square_meter_price'].mean()
# Out:
# 110058.24702032938

# %%
data_long_sales['locality_name'].value_counts()
# Out:
# Санкт-Петербург                   126
# Пушкин                              4
# Петергоф                            3
# Коммунар                            3
# Всеволожск                          2
# Сертолово                           2
# Павловск                            2
# поселок Мурино                      2
# Кронштадт                           2
# поселок Молодежное                  1
# поселок Шушары                      1
# Кириши                              1
# Лодейное Поле                       1
# поселок Тельмана                    1
# деревня Новое Девяткино             1
# поселок городского типа Вырица      1
# деревня Калитино                    1
# Шлиссельбург                        1
# Ломоносов                           1
# Красное Село                        1
# Колпино                             1
# поселок Лисий Нос                   1
# Сестрорецк                          1
# Отрадное                            1
# деревня Нурма                       1
# деревня Кудрово                     1
# Кудрово                             1
# поселок Парголово                   1
# поселок Рябово                      1
# Name: locality_name, dtype: int64

# %% [markdown]
# Посмотрим на общую площадь.

# %%
data_long_sales['total_area'].mean()
# Out:
# 81.38060240963856

# %% [markdown]
# Вывод: Более долго продаются квартиры бОльшей площади с чуть больше среднего ценой квадратного метра, с общей ценой квартиры выше среднего.

# %% [markdown]
# Посмотрим на квартиры, продававшиеся быстро.

# %%
data['days_exposition'].hist(bins=20, figsize=(10,5), range=(0,10))

# %%
data_fast_sales=data.query('days_exposition<10').copy()
data_fast_sales
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 11                9  3300000.00       44.00           2018-08-27      2
# 53                7  4300000.00       39.10           2017-11-10      1
# 62                0  4800000.00       78.60           2017-09-17      3
# 94                3  3500000.00       29.50           2019-04-26      1
# 100              16  3800000.00       38.60           2018-02-22      1
# ...             ...         ...         ...                  ...    ...
# 23513            12  8300000.00       62.60           2017-02-15      2
# 23596            10  3500000.00       43.50           2017-12-05      2
# 23606             0  2850000.00       68.00           2018-07-29      1
# 23647             9  5700000.00       45.60           2019-01-09      1
# 23661            19  8100000.00       75.40           2018-09-19      3
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 11               2.65             5        31.00      4         False   False
# 53               2.65            25        15.40     13         False   False
# 62               2.80             9        48.80      5         False   False
# 94               2.50             5        15.60      2         False   False
# 100              2.65             9        18.00      6         False   False
# ...               ...           ...          ...    ...           ...     ...
# 23513            2.70            16        32.90      8         False   False
# 23596            2.50             9        27.00      6         False   False
# 23606            3.00             5        41.00      3         False   False
# 23647            2.75            16        18.70      6         False   False
# 23661            2.75            12        47.90     11         False   False
#
#        open_plan  kitchen_area  balcony      locality_name  airports_nearest  \
# 11         False          6.00        1          Ломоносов          48252.00
# 53         False         15.50        2  поселок Парголово          52611.00
# 62         False         11.90        2          Сертолово               nan
# 94         False          5.50        1    Санкт-Петербург          12921.00
# 100        False          8.40        2    Санкт-Петербург          36450.00
# ...          ...           ...      ...                ...               ...
# 23513      False         11.30        2    Санкт-Петербург          29077.00
# 23596      False          6.20        0    Санкт-Петербург          49094.00
# 23606      False         10.00        0    Санкт-Петербург          38473.00
# 23647      False         17.60        0    Санкт-Петербург          10934.00
# 23661      False          9.40        0    Санкт-Петербург          14727.00
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 11                51677.00                 0            nan                 0
# 53                18783.00                 0            nan                 0
# 62                     nan                 0            nan                 0
# 94                 7303.00                 0            nan                 0
# 100               13364.00                 0            nan                 0
# ...                    ...               ...            ...               ...
# 23513             10858.00                 0            nan                 0
# 23596             16671.00                 0            nan                 0
# 23606              7740.00                 2         560.00                 3
# 23647             12551.00                 0            nan                 0
# 23661             16771.00                 0            nan                 0
#
#        ponds_nearest  days_exposition  living_area_ratio  kitchen_area_ratio  \
# 11               nan             7.00               0.70                0.14
# 53               nan             6.00               0.39                0.40
# 62               nan             5.00               0.62                0.15
# 94               nan             4.00               0.53                0.19
# 100              nan             8.00               0.47                0.22
# ...              ...              ...                ...                 ...
# 23513            nan             7.00               0.53                0.18
# 23596            nan             6.00               0.62                0.14
# 23606         327.00             4.00               0.60                0.15
# 23647            nan             8.00               0.41                0.39
# 23661            nan             6.00               0.64                0.12
#
#        square_meter_price  weekday_exposition  month_exposition  \
# 11               75000.00                   0                 8
# 53              109974.42                   4                11
# 62               61068.70                   6                 9
# 94              118644.07                   4                 4
# 100              98445.60                   3                 2
# ...                   ...                 ...               ...
# 23513           132587.86                   2                 2
# 23596            80459.77                   1                12
# 23606            41911.76                   6                 7
# 23647           125000.00                   2                 1
# 23661           107427.06                   2                 9
#
#        year_exposition floor_category  floor_category_id  last_price_thousand
# 11                2018    другой этаж                  2              3300.00
# 53                2017    другой этаж                  2              4300.00
# 62                2017    другой этаж                  2              4800.00
# 94                2019    другой этаж                  2              3500.00
# 100               2018    другой этаж                  2              3800.00
# ...                ...            ...                ...                  ...
# 23513             2017    другой этаж                  2              8300.00
# 23596             2017    другой этаж                  2              3500.00
# 23606             2018    другой этаж                  2              2850.00
# 23647             2019    другой этаж                  2              5700.00
# 23661             2018    другой этаж                  2              8100.00
#
# [1130 rows x 31 columns]

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# `query` возвращает копию, поэтому не надо копировать второй раз, тем более ты копию не модифицируешь
# </div>

# %% [markdown]
# 1130 квартир продалось за период менее 10 дней.

# %% [markdown]
# Посмотрим на среднюю цену квартиры.

# %%
data_fast_sales['last_price'].mean()
# Out:
# 5395332.83539823

# %% [markdown]
# Посмотрим на среднюю цену квадратного метра.

# %%
data_fast_sales['square_meter_price'].mean()
# Out:
# 99513.92688694519

# %% [markdown]
# Посмотрим на общую площадь.

# %%
data_fast_sales['total_area'].mean()
# Out:
# 52.80733628318583

# %% [markdown]
# Средняя цена квадратного метра у быстро продающихся квартир меньше, чем у долго продающихся, общая цена тоже меньше, как и общая площадь.

# %% [markdown]
# Посмотрим на местоположение.

# %%
data_fast_sales['locality_name'].value_counts()
# Out:
# Санкт-Петербург                   803
# поселок Мурино                     34
# поселок Парголово                  21
# Колпино                            20
# Пушкин                             19
#                                  ...
# поселок Семиозерье                  1
# поселок Терволово                   1
# поселок Первомайское                1
# поселок городского типа Важины      1
# деревня Старосиверская              1
# Name: locality_name, Length: 84, dtype: int64

# %% [markdown]
# Мы видим, что среди быстро продающихся квартир гораздо больше других локаций, чем среди долго продающихся. Квартиры в Ленинградской области "подвисают" в продаже относительно меньше, чем по С-Петербурге.

# %% [markdown]
# Посмотрим взаимосвязь скорости продажи квартиры и ее местоположения.

# %% [markdown]
# Дольше всего продаются квартиры, находящиеся по направлению трассы С-Петербург - Москва, в районе Лен.области с сомнительной экологией.

# %%
locality_days_exposition_pivot=data.pivot_table(index='locality_name', values=['days_exposition', 'total_area'], aggfunc='median')
locality_days_exposition_pivot.sort_values(by='days_exposition', ascending=False).head(10)
# Out:
#                             days_exposition  total_area
# locality_name
# поселок Севастьяново                1069.00       62.00
# поселок Молодежное                  1043.00       51.40
# деревня Рабитицы                    1007.00       55.40
# поселок Коробицыно                   750.00       58.45
# поселок Любань                       654.00       50.00
# деревня Большая Пустомержа           627.00       53.50
# деревня Зимитицы                     610.00       58.00
# поселок Рябово                       574.50       72.25
# деревня Мины                         540.00       48.00
# поселок Суйда                        503.00       56.70

# %% [markdown]
# Быстрее всего продающиеся квартиры находятся в Лен.области на карельском перешейке

# %%
locality_days_exposition_pivot.sort_values(by='days_exposition', ascending=True).head(10)
# Out:
#                                  days_exposition  total_area
# locality_name
# поселок Володарское                         5.00       47.20
# поселок Заводской                           5.00       29.20
# садовое товарищество Садко                  7.00       56.00
# коттеджный поселок Счастье                  7.00       72.00
# деревня Яльгелево                           7.00       44.90
# село Шум                                    9.00       59.00
# поселок Семиозерье                          9.00       56.00
# деревня Малая Романовка                     9.00       66.80
# поселок Новогорелово                       10.00       40.85
# поселок Платформа 69-й километр            18.00       52.70

# %%
print('В Санкт-Петербурге квартиры продаются в среднем за {} дня'.format(data.query('locality_name=="Санкт-Петербург"')['days_exposition'].mean().astype('int')))
# Out:
# В Санкт-Петербурге квартиры продаются в среднем за 182 дня

# %% [markdown]
# Посмотрим взаимосвязь скорости продажи квартиры и удаленности ее от центра Санкт-Петербурга (в первом приближении для всех квартир, затем - для Санкт-Петербурга).

# %%
data.plot(x='cityCenters_nearest', y='days_exposition', kind='hexbin', sharex=False, xlim=(0,20_000), ylim=(0,150))

# %%
data['cityCenters_nearest'].corr(data['days_exposition'])
# Out:
# -0.06060691579222224

# %% [markdown]
# Коэффициент корреляции практически нулевой.

# %%
data.query('locality_name=="Санкт-Петербург"').plot(x='cityCenters_nearest', y='days_exposition', kind='hexbin', sharex=False, xlim=(0,20_000), ylim=(0,200))

# %%
data.query('locality_name=="Санкт-Петербург"')['cityCenters_nearest'].corr(data['days_exposition'])
# Out:
# -0.13842712425324044

# %% [markdown]
# Коэффициент корреляции также очень мал (отрицателен).

# %% [markdown]
# Посмотрим взаимосвязь скорости продажи квартиры и цены за квадратный метр.

# %%
data.plot(x='square_meter_price', y='days_exposition', kind='hexbin', sharex=False, xlim=(0,250_000), ylim=(0,200))

# %% [markdown]
# Визуально можем сделать вывод о том, что при одной и той же цене за квадратный метр квартиры продаются с разной скоростью. Посмотрим на коэффициент корреляции.

# %%
data['square_meter_price'].corr(data['days_exposition'])
# Out:
# 0.048120061392986066

# %% [markdown]
# Он также очень далек от 1, что означает, что зависимости как таковой нет, несмотря на то, что (в среднем) мы увидели, что быстрее продаются небольшие квартиры с недорогим квадратным метром.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Важно понимать, что корреляция не все зависимости описывает, а только то, где один параметр увеличивается или уменьшается с ростом другого, иначе гвооря оценивает близость к линейной зависимости
# </div>

# %% [markdown]
# Посмотрим взаимосвязь скорости продажи квартиры и ее площади.

# %%
data.plot(x='total_area', y='days_exposition', kind='hexbin', sharex=False, xlim=(0,100), ylim=(0,200))

# %%
data['total_area'].corr(data['days_exposition'])
# Out:
# 0.14967517208715722

# %% [markdown]
# Коэфициент корреляции также очень далек от 1, что означает, что зависимости как таковой нет, несмотря на то, как и прежде, (в среднем) быстрее продаются небольшие квартиры с недорогим квадратным метром.

# %% [markdown]
# Посмотрим, в каком году квартиры продавались быстрее всего.

# %%
data.pivot_table(index='year_exposition', values='days_exposition', aggfunc='mean').sort_values(by='days_exposition', ascending=False)
# Out:
#                  days_exposition
# year_exposition
# 2014                      910.98
# 2015                      648.04
# 2016                      320.75
# 2017                      158.96
# 2018                       94.34
# 2019                       30.93

# %% [markdown]
# По данным этой сводной таблицы квартиры год от года продаются всё быстрее и быстрее, и за шесть лет скорость продажи квартир увеличилась в 30 раз. Возможно, это связано с тем, что ранее к сервису обращались только в том случае, если недвижимость было не продать другими способами, и сервис был развит мало (к тому же мы ранее видели, что статистика за 2014 год собирается только с ноября, а в 2019 году - только по май). Посмотрим, сколько объявлений (как с указанным количеством дней размещения, так и без этих данных) было на сервисе в каком году.

# %%
days_pivot=data.pivot_table(index='year_exposition', values=['month_exposition', 'days_exposition'], aggfunc='count').sort_values(by='year_exposition', ascending=False)
days_pivot.columns=['with_days_exposition_data', 'without_days_exposition_data']
days_pivot
# Out:
#                  with_days_exposition_data  without_days_exposition_data
# year_exposition
# 2019                                  1083                          2879
# 2018                                  7560                          8519
# 2017                                  7919                          8190
# 2016                                  2716                          2783
# 2015                                  1121                          1191
# 2014                                   119                           137

# %% [markdown]
# ######   Вывод: судя по средним данным, быстрее продаются меньшие по площади, более дешевые квартиры (как по общей цене, так и по цене за квадратный метр), но прямой зависимости между этими факторами (по-отдельности) и скоростью продажи квартиры не обнаружено.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# 👍 Графики кстати лучше подписывать
# </div>

# %% [markdown]
# ### Редкие и выбивающиеся значения

# %% [markdown]
# Когда мы рассматривали цену квартиры, мы нашли квартиру за 12 тысяч рублей с неподобающей этой цене площадью и расположением в Санкт-Петербурге. Очевидно, что данная запись некорректна, и этот выброс следует удалить.

# %%
data=data.query('last_price_thousand>12.2')
len(data)
# Out:
# 23698

# %% [markdown]
# Данная строка удалена, записей стало на 1 меньше.

# %% [markdown]
# Изучая данные о высоте потолков, мы нашли потолок высотой 100 метров. Посмотрим, какие еще есть потолки.

# %%
data_pivot_ceiling_height=data.pivot_table(index='ceiling_height', values='total_area', aggfunc='count')
data_pivot_ceiling_height.sort_values(by='ceiling_height', ascending=False).head(10)
# Out:
#                 total_area
# ceiling_height
# 100.00                   1
# 32.00                    2
# 27.50                    1
# 27.00                    8
# 26.00                    1
# 25.00                    7
# 24.00                    1
# 22.60                    1
# 20.00                    1
# 14.00                    1

# %% [markdown]
# Потолок в 100 метров есть только в одной квартире. 100 метров - это высота 30-этажного здания.

# %%
data.query('ceiling_height==100.0')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 22869             0 15000000.00       25.00           2018-07-25      1
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 22869          100.00             5        14.00      5          True   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 22869      False         11.00        5  Санкт-Петербург          34963.00
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 22869              8283.00                 1         223.00                 3
#
#        ponds_nearest  days_exposition  living_area_ratio  kitchen_area_ratio  \
# 22869          30.00            19.00               0.56                0.44
#
#        square_meter_price  weekday_exposition  month_exposition  \
# 22869           600000.00                   2                 7
#
#        year_exposition  floor_category  floor_category_id  last_price_thousand
# 22869             2018  последний этаж                  3             15000.00

# %% [markdown]
# Апартаменты в СПб общей площадью 25 кв на 5 этаже 5-этажного дома в 8 км от центра города возле прудов и парка по цене 600 тыс.рублей за квадратный метр и общей ценой 15 млн. рублей. Всё может быть кроме высоты потолков в 100 метров. Близко к центру города даже зданий такой высоты нет. Удалим строку.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Коммеентарий ревьюера</h2>
#
# Ну 30 и 20 метров тоже очень высокие потолки :)
# </div>

# %%
data=data.query('ceiling_height<100')
len(data)
# Out:
# 23697

# %% [markdown]
# ### Факторы, больше всего влияющие на стоимость квартиры

# %% [markdown]
# Изучим, зависит ли цена от площади, числа комнат, удалённости от центра. Изучим зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом, также от даты размещения: дня недели, месяца и года.

# %% [markdown]
# 1. Взаимосвязь общей цены и общей площади квартиры.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23697 entries, 0 to 23698
# Data columns (total 31 columns):
# total_images            23697 non-null int64
# last_price              23697 non-null float64
# total_area              23697 non-null float64
# first_day_exposition    23697 non-null datetime64[ns]
# rooms                   23697 non-null int64
# ceiling_height          23697 non-null float64
# floors_total            23697 non-null int64
# living_area             23697 non-null float64
# floor                   23697 non-null int64
# is_apartment            23697 non-null bool
# studio                  23697 non-null bool
# open_plan               23697 non-null bool
# kitchen_area            23697 non-null float64
# balcony                 23697 non-null int64
# locality_name           23697 non-null object
# airports_nearest        18155 non-null float64
# cityCenters_nearest     18247 non-null float64
# parks_around3000        23697 non-null int64
# parks_nearest           8077 non-null float64
# ponds_around3000        23697 non-null int64
# ponds_nearest           9109 non-null float64
# days_exposition         20516 non-null float64
# living_area_ratio       23697 non-null float64
# kitchen_area_ratio      23697 non-null float64
# square_meter_price      23697 non-null float64
# weekday_exposition      23697 non-null int64
# month_exposition        23697 non-null int64
# year_exposition         23697 non-null int64
# floor_category          23697 non-null object
# floor_category_id       23697 non-null int64
# last_price_thousand     23697 non-null float64
# dtypes: bool(3), datetime64[ns](1), float64(14), int64(11), object(2)
# memory usage: 5.3+ MB

# %%
data.plot(x='total_area', y='last_price_thousand', kind='hexbin', sharex=False, xlim=(0,100), ylim=(0,20000))

# %% [markdown]
# Квартиры разного метража продаются по схожей цене.

# %%
data['total_area'].corr(data['last_price_thousand'])
# Out:
# 0.6537946269642676

# %% [markdown]
# Коэффициент корреляции гораздо больше нуля, чем в предыдущих случаях, но всё же ближе к 0.5, чем к 1. Это средняя зависимость.

# %% [markdown]
# 2. Взаимосвязь цены квадратного метра и общей площади квартиры.

# %%
data.plot(x='total_area', y='square_meter_price', kind='hexbin', sharex=False, xlim=(0,100), ylim=(0,200000))

# %%
data['total_area'].corr(data['square_meter_price'])
# Out:
# 0.3031673150304947

# %% [markdown]
# Зависимость слабая.

# %% [markdown]
# 3. Взаимосвязь общей цены и числа комнат.

# %%
data.plot(x='rooms', y='last_price_thousand', kind='hexbin', sharex=False, xlim=(0,5), ylim=(0,50000))

# %%
data['last_price'].corr(data['rooms'])
# Out:
# 0.36338871711713

# %% [markdown]
# Зависимость незначительная, слабая. Квартиры с одним и тем же количеством комнат продаются по разной цене.

# %% [markdown]
# 4. Взаимосвязь цены квадратного метра и числа комнат.

# %%
data.plot(x='rooms', y='square_meter_price', kind='hexbin', sharex=False, xlim=(0,5), ylim=(0,200000))

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Тут лучше было бы использовать `stripplot` да и в целом лучше обычный `scatter`, а не `hex`
# </div>

# %%
data['square_meter_price'].corr(data['rooms'])
# Out:
# 0.05595387063173171

# %%
data_pivot_square_meter_price_rooms=data.pivot_table(index='rooms', values='square_meter_price', aggfunc='mean')
data_pivot_square_meter_price_rooms.sort_values(by='rooms', ascending=True)
# Out:
#        square_meter_price
# rooms
# 0               108513.11
# 1               100756.22
# 2                95501.67
# 3                97151.15
# 4               110331.61
# 5               126750.34
# 6               140718.81
# 7               163569.92
# 8               184651.17
# 9               105027.15
# 10               98009.93
# 11              132639.74
# 12              466666.67
# 14               92827.68
# 15              110169.49
# 16              105555.56
# 19               86091.83

# %% [markdown]
# Посмотрим на количество квартир в каждой группе количества комнат. С количеством комнат больше 7 - единицы квартир.

# %%
data_pivot_square_meter_price_rooms=data.pivot_table(index='rooms', values='square_meter_price', aggfunc='count')
data_pivot_square_meter_price_rooms.sort_values(by='rooms', ascending=True)
# Out:
#        square_meter_price
# rooms
# 0                     197
# 1                    8046
# 2                    7939
# 3                    5814
# 4                    1180
# 5                     326
# 6                     105
# 7                      59
# 8                      12
# 9                       8
# 10                      3
# 11                      2
# 12                      1
# 14                      2
# 15                      1
# 16                      1
# 19                      1

# %%
data_pivot_square_meter_price_rooms.query('rooms<=7').plot()

# %% [markdown]
# Прямая зависимость отсутствует, но после количества комнат 2 шт., средняя цена квадратного метра начинает падать.

# %% [markdown]
# 5. Взаимосвязь общей цены и удаленности от центра.

# %%
data.plot(x='cityCenters_nearest', y='last_price_thousand', kind='hexbin', sharex=False, xlim=(0,20000), ylim=(0,15000))

# %% [markdown]
# Квартиры на одинаковом расстоянии от центра продаются по разной цене.

# %%
data['last_price'].corr(data['cityCenters_nearest'])
# Out:
# -0.20612239617905953

# %% [markdown]
# Чем больше расстояние от центра, тем меньше цена, но зависимость очень слабая.

# %% [markdown]
# 6. Взаимосвязь цены квадратного метра и удаленности от центра.

# %%
data.plot(x='cityCenters_nearest', y='square_meter_price', kind='hexbin', sharex=False, xlim=(0,20000), ylim=(0,250000))

# %% [markdown]
# Квартиры на разном удалении от центра города могут иметь одну и ту же цену квадратного метра.

# %%
data['square_meter_price'].corr(data['cityCenters_nearest'])
# Out:
# -0.31716231906083103

# %% [markdown]
# В целом, чем больше расстояние от центра, тем меньше цена квадратного метра, но зависимость очень слабая.

# %% [markdown]
# 7. Зависимость общей цены от этажа (первый, последний и т.д.)

# %%
data_pivot_last_price_thousand_floor_category=data.pivot_table(index='floor_category_id', values='last_price_thousand', aggfunc='median')
data_pivot_last_price_thousand_floor_category.sort_values(by='floor_category_id', ascending=True)
# Out:
#                    last_price_thousand
# floor_category_id
# 1                              3900.00
# 2                              4850.00
# 3                              4300.00

# %% [markdown]
# Медианная цена квартир не на первом и не на последнем этаже выше, чем на первом и последнем. На первом самая низкая.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Ну вот имхо `id` только хуже сказались на читаемости, т.к. уже не понятно за что какой `id` отвечает
# </div>

# %% [markdown]
# 7. Зависимость цены квадратного метра от этажа (первый, последний и т.д.)

# %%
data_pivot_square_meter_price_floor_category=data.pivot_table(index='floor_category_id', values='square_meter_price', aggfunc='median')
data_pivot_square_meter_price_floor_category.sort_values(by='floor_category_id', ascending=True)
# Out:
#                    square_meter_price
# floor_category_id
# 1                            81302.85
# 2                            98290.60
# 3                            87639.13

# %% [markdown]
# Тот же вывод в отношении цены квадратного метра: он дороже на "другом" этаже, чем на первом или последнем.

# %% [markdown]
# 8. Зависимость общей цены от даты размещения (день недели, месяц, год)

# %%
data_pivot_last_price_weekday=data.pivot_table(index='weekday_exposition', values='last_price_thousand', aggfunc='median')
data_pivot_last_price_weekday.sort_values(by='last_price_thousand', ascending=False)
# Out:
#                     last_price_thousand
# weekday_exposition
# 1                               4730.00
# 2                               4700.00
# 0                               4650.00
# 3                               4650.00
# 4                               4585.00
# 5                               4555.00
# 6                               4550.00

# %% [markdown]
# Средняя цена примерно одинакова в любой день недели, и коэффициент корреляции отсутствует.

# %%
data['weekday_exposition'].corr(data['last_price_thousand'])
# Out:
# 0.0015525629052340621

# %% [markdown]
# То же касается и цены квадратного метра.

# %%
data_pivot_square_meter_price_weekday=data.pivot_table(index='weekday_exposition', values='square_meter_price', aggfunc='median')
data_pivot_square_meter_price_weekday.sort_values(by='weekday_exposition', ascending=True)
# Out:
#                     square_meter_price
# weekday_exposition
# 0                             94688.91
# 1                             95634.10
# 2                             95473.81
# 3                             95143.88
# 4                             94616.16
# 5                             93545.72
# 6                             94501.72

# %%
data_pivot_last_price_month=data.pivot_table(index='month_exposition', values='last_price_thousand', aggfunc='median')
data_pivot_last_price_month.sort_values(by='last_price_thousand', ascending=False)
# Out:
#                   last_price_thousand
# month_exposition
# 4                             4800.00
# 9                             4700.00
# 11                            4700.00
# 12                            4700.00
# 2                             4650.00
# 3                             4650.00
# 7                             4650.00
# 1                             4600.00
# 8                             4570.00
# 10                            4570.00
# 5                             4515.00
# 6                             4400.00

# %%
data['month_exposition'].corr(data['last_price_thousand'])
# Out:
# 0.0027489641017021363

# %%
data_pivot_square_meter_price_month=data.pivot_table(index='month_exposition', values='square_meter_price', aggfunc='median')
data_pivot_square_meter_price_month.sort_values(by='square_meter_price', ascending=False)
# Out:
#                   square_meter_price
# month_exposition
# 4                           96451.61
# 8                           96026.32
# 9                           95607.24
# 11                          95588.24
# 3                           95293.47
# 1                           95222.44
# 2                           95000.00
# 7                           95000.00
# 12                          94262.30
# 10                          94202.90
# 5                           92857.14
# 6                           92799.54

# %% [markdown]
# Зависимость цены от года размещения объявления также отсутствует.

# %%
data_pivot_last_price_year=data.pivot_table(index='year_exposition', values='last_price_thousand', aggfunc='median')
data_pivot_last_price_year.sort_values(by='last_price_thousand', ascending=False)
# Out:
#                  last_price_thousand
# year_exposition
# 2014                         7700.00
# 2015                         5350.00
# 2019                         5050.00
# 2016                         4550.00
# 2018                         4550.00
# 2017                         4500.00

# %%
data['last_price_thousand'].corr(data['year_exposition'])
# Out:
# -0.043072701761918054

# %%
data_pivot_square_meter_price_year=data.pivot_table(index='year_exposition', values='square_meter_price', aggfunc='median')
data_pivot_square_meter_price_year.sort_values(by='square_meter_price', ascending=False)
# Out:
#                  square_meter_price
# year_exposition
# 2014                      107000.00
# 2019                      103328.87
# 2018                       95688.49
# 2015                       93414.63
# 2017                       92565.09
# 2016                       91743.12

# %%
data['square_meter_price'].corr(data['year_exposition'])
# Out:
# 0.00841010636592841

# %% [markdown]
# Цена квадратного метра была самой высокой в 2014 и 2019 году, а в 2016 - наименьшей, как иллюстрация кризиса на рынке недвижимости в СПб в 2016 году.

# %%
data_pivot_square_meter_price_year.plot()

# %% [markdown]
# 9. Зависимость между ценой и ценой квадратного метра:

# %%
data['last_price'].corr(data['square_meter_price'])
# Out:
# 0.7377412040525995

# %% [markdown]
# Зависимость между общей ценой и ценой квадратного метра значительная, она прямая. Чем выше цена, тем выше и стоимость одного квадратного метра в квартире. В более дорогих квартирах даже один метр площади дороже.

# %% [markdown]
# Нашлись факторы, имеющие влияние на цену (цену квадратного метра), но влияние каждого фактора по-отдельности незначительное.

# %%
data_for_plotting_scatter=data.copy()
data_for_plotting_scatter=data_for_plotting_scatter.drop(
    ['total_images', 'first_day_exposition', 'rooms', 'ceiling_height', 'floors_total', 
     'living_area', 'floor', 'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony', 
     'locality_name', 'airports_nearest', 'parks_around3000', 'parks_nearest', 'ponds_around3000', 
     'ponds_nearest', 'days_exposition', 'living_area_ratio', 'kitchen_area_ratio', 
     'weekday_exposition', 'month_exposition', 'year_exposition', 'floor_category', 
     'floor_category_id', 'cityCenters_nearest'], axis=1
)
data_for_plotting_scatter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23697 entries, 0 to 23698
# Data columns (total 4 columns):
# last_price             23697 non-null float64
# total_area             23697 non-null float64
# square_meter_price     23697 non-null float64
# last_price_thousand    23697 non-null float64
# dtypes: float64(4)
# memory usage: 925.7 KB

# %%
pd.plotting.scatter_matrix(data_for_plotting_scatter, figsize=(9, 9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf759750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf70e810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf6bcfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf67b7d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf62af90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf5e87d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf617fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf5d5810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf5df390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf58ed10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf4fbbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf4b0890>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf46cc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf4a38d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf461c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f32bf418910>]],
#       dtype=object)

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Отличный итог, в тетрадке по умолчанию рендерится последняя строка, так что чтобы не выводился `array` из `matplot` объектов, можно пустой `print` доабвить внизу
# </div>

# %% [markdown]
# ### Топ-10 населённых пунктов с наибольшим числом объявлений

# %% [markdown]
# Рассмотрим 10 населённых пунктов с наибольшим числом объявлений, получим названия этих населенных пунктов в виде списка.

# %%
locality_pivot=data.pivot_table(index='locality_name', values='total_area', aggfunc='count')
locality_pivot.columns=['sales_quantity']
locality_pivot_top=locality_pivot.sort_values(by='sales_quantity', ascending=False).head(10)
locality_pivot_top
# Out:
#                    sales_quantity
# locality_name
# Санкт-Петербург             15768
# поселок Мурино                556
# поселок Шушары                440
# Всеволожск                    398
# Пушкин                        369
# Колпино                       338
# поселок Парголово             327
# Гатчина                       307
# деревня Кудрово               299
# Выборг                        237

# %% [markdown]
# data['last_price'].corr(data['square_meter_price'])

# %%
top_ten_localities_list=locality_pivot_top.index.unique().tolist()
top_ten_localities_list
# Out:
# ['Санкт-Петербург',
#  'поселок Мурино',
#  'поселок Шушары',
#  'Всеволожск',
#  'Пушкин',
#  'Колпино',
#  'поселок Парголово',
#  'Гатчина',
#  'деревня Кудрово',
#  'Выборг']

# %% [markdown]
# Выделим все записи из data, населенные пункты которых содержатся в найденном нами "Топ-10"

# %%
data_top_ten_localities=data.query('locality_name in @top_ten_localities_list')
data_top_ten_localities
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20 13000000.00      108.00           2019-03-07      3
# 1                 7  3350000.00       40.40           2018-12-04      1
# 2                10  5196000.00       56.00           2015-08-20      2
# 3                 0 64900000.00      159.00           2015-07-24      3
# 4                 2 10000000.00      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23689            13  3550000.00       35.30           2018-02-28      1
# 23690             3  5500000.00       52.00           2018-07-19      2
# 23691            11  9470000.00       72.90           2016-10-13      2
# 23694             9  9700000.00      133.81           2017-03-21      3
# 23697            13 11475000.00       76.75           2017-03-28      2
#
#        ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0                2.70            16        51.00      8         False   False
# 1                2.65            11        18.60      1         False   False
# 2                2.65             5        34.30      4         False   False
# 3                2.65            14        90.29      9         False   False
# 4                3.03            14        32.00     13         False   False
# ...               ...           ...          ...    ...           ...     ...
# 23689            2.86            15        16.30      4         False   False
# 23690            2.65             5        31.00      2         False   False
# 23691            2.75            25        40.30      7         False   False
# 23694            3.70             5        73.30      3         False   False
# 23697            3.00            17        43.58     12         False   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 0          False         25.00        0  Санкт-Петербург          18863.00
# 1          False         11.00        2   поселок Шушары          12817.00
# 2          False          8.30        0  Санкт-Петербург          21741.00
# 3          False         27.41        0  Санкт-Петербург          28098.00
# 4          False         41.00        0  Санкт-Петербург          31856.00
# ...          ...           ...      ...              ...               ...
# 23689      False          9.10        2  Санкт-Петербург          17284.00
# 23690      False          6.00        0  Санкт-Петербург          20151.00
# 23691      False         10.60        1  Санкт-Петербург          19424.00
# 23694      False         13.83        0  Санкт-Петербург          24665.00
# 23697      False         23.30        2  Санкт-Петербург          39140.00
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0                 16028.00                 1         482.00                 2
# 1                 18603.00                 0            nan                 0
# 2                 13933.00                 1          90.00                 2
# 3                  6800.00                 2          84.00                 3
# 4                  8098.00                 2         112.00                 1
# ...                    ...               ...            ...               ...
# 23689             16081.00                 1         353.00                 2
# 23690              6263.00                 1         300.00                 0
# 23691              4489.00                 0            nan                 1
# 23694              4232.00                 1         796.00                 3
# 23697             10364.00                 2         173.00                 3
#
#        ponds_nearest  days_exposition  living_area_ratio  kitchen_area_ratio  \
# 0             755.00              nan               0.47                0.23
# 1                nan            81.00               0.46                0.27
# 2             574.00           558.00               0.61                0.15
# 3             234.00           424.00               0.57                0.17
# 4              48.00           121.00               0.32                0.41
# ...              ...              ...                ...                 ...
# 23689         652.00            29.00               0.46                0.26
# 23690            nan            15.00               0.60                0.12
# 23691         806.00           519.00               0.55                0.15
# 23694         381.00              nan               0.55                0.10
# 23697         196.00           602.00               0.57                0.30
#
#        square_meter_price  weekday_exposition  month_exposition  \
# 0               120370.37                   3                 3
# 1                82920.79                   1                12
# 2                92785.71                   3                 8
# 3               408176.10                   4                 7
# 4               100000.00                   1                 6
# ...                   ...                 ...               ...
# 23689           100566.57                   2                 2
# 23690           105769.23                   3                 7
# 23691           129903.98                   3                10
# 23694            72490.85                   1                 3
# 23697           149511.40                   1                 3
#
#        year_exposition floor_category  floor_category_id  last_price_thousand
# 0                 2019    другой этаж                  2             13000.00
# 1                 2018    первый этаж                  1              3350.00
# 2                 2015    другой этаж                  2              5196.00
# 3                 2015    другой этаж                  2             64900.00
# 4                 2018    другой этаж                  2             10000.00
# ...                ...            ...                ...                  ...
# 23689             2018    другой этаж                  2              3550.00
# 23690             2018    другой этаж                  2              5500.00
# 23691             2016    другой этаж                  2              9470.00
# 23694             2017    другой этаж                  2              9700.00
# 23697             2017    другой этаж                  2             11475.00
#
# [19039 rows x 31 columns]

# %%
print('Для Топ-10 населенных пунктов это {} объявлений.'.format(len(data_top_ten_localities)))
# Out:
# Для Топ-10 населенных пунктов это 19039 объявлений.

# %% [markdown]
# Определим среднюю цену квадратного метра в этих населенных пунктах.

# %%
data_top_ten_localities_pivot=data_top_ten_localities.pivot_table(index='locality_name', values='square_meter_price', aggfunc='mean')
data_top_ten_localities_pivot
# Out:
#                    square_meter_price
# locality_name
# Всеволожск                   68654.47
# Выборг                       58141.91
# Гатчина                      68746.15
# Колпино                      75424.58
# Пушкин                      103125.82
# Санкт-Петербург             114761.69
# деревня Кудрово              92473.55
# поселок Мурино               85681.76
# поселок Парголово            90175.91
# поселок Шушары               78677.36

# %% [markdown]
# Населенный пункт из Топ-10 с самой высокой средней стоимостью квадратного метра:

# %%
data_top_ten_localities_pivot.query('square_meter_price==square_meter_price.max()')
# Out:
#                  square_meter_price
# locality_name
# Санкт-Петербург           114761.69

# %% [markdown]
# Населенный пункт из Топ-10 с самой низкой средней стоимостью квадратного метра:

# %%
data_top_ten_localities_pivot.query('square_meter_price==square_meter_price.min()')
# Out:
#                square_meter_price
# locality_name
# Выборг                   58141.91

# %% [markdown]
# Выборг и Гатчина дальше всех от Санкт-Петербурга. Все остальные населенные пункты - фактически его пригороды.

# %% [markdown]
# ### Предложения квартир (расстояние до центра)

# %% [markdown]
# Выделим по локации Санкт-Петербург. Сформируем датафрейм spb_data и будем работать с ним.

# %%
spb_data=data.loc[data['locality_name']=='Санкт-Петербург'].copy()
spb_data.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20 13000000.00      108.00           2019-03-07      3
# 2             10  5196000.00       56.00           2015-08-20      2
# 3              0 64900000.00      159.00           2015-07-24      3
# 4              2 10000000.00      100.00           2018-06-19      2
# 7              5  7915000.00       71.60           2019-04-18      2
# 9             18  5400000.00       61.00           2017-02-26      3
# 10             5  5050000.00       39.60           2017-11-16      1
# 15            16  4650000.00       39.00           2017-11-18      1
# 16            11  6700000.00       82.00           2017-11-23      3
# 17             6  4180000.00       36.00           2016-09-09      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0             2.70            16        51.00      8         False   False
# 2             2.65             5        34.30      4         False   False
# 3             2.65            14        90.29      9         False   False
# 4             3.03            14        32.00     13         False   False
# 7             2.65            24        40.66     22         False   False
# 9             2.50             9        43.60      7         False   False
# 10            2.67            12        20.30      3         False   False
# 15            2.65            14        20.50      5         False   False
# 16            3.05             5        55.60      1         False   False
# 17            2.65            17        16.50      7         False   False
#
#     open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 0       False         25.00        0  Санкт-Петербург          18863.00
# 2       False          8.30        0  Санкт-Петербург          21741.00
# 3       False         27.41        0  Санкт-Петербург          28098.00
# 4       False         41.00        0  Санкт-Петербург          31856.00
# 7       False         18.90        2  Санкт-Петербург          23982.00
# 9       False          6.50        2  Санкт-Петербург          50898.00
# 10      False          8.50        0  Санкт-Петербург          38357.00
# 15      False          7.60        1  Санкт-Петербург          12900.00
# 16      False          9.00        0  Санкт-Петербург          22108.00
# 17      False         11.00        1  Санкт-Петербург          33564.00
#
#     cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0              16028.00                 1         482.00                 2
# 2              13933.00                 1          90.00                 2
# 3               6800.00                 2          84.00                 3
# 4               8098.00                 2         112.00                 1
# 7              11634.00                 0            nan                 0
# 9              15008.00                 0            nan                 0
# 10             13878.00                 1         310.00                 2
# 15             14259.00                 1         590.00                 1
# 16             10698.00                 3         420.00                 0
# 17             14616.00                 0            nan                 1
#
#     ponds_nearest  days_exposition  living_area_ratio  kitchen_area_ratio  \
# 0          755.00              nan               0.47                0.23
# 2          574.00           558.00               0.61                0.15
# 3          234.00           424.00               0.57                0.17
# 4           48.00           121.00               0.32                0.41
# 7             nan              nan               0.57                0.26
# 9             nan           289.00               0.71                0.11
# 10         553.00           137.00               0.51                0.21
# 15         296.00            19.00               0.53                0.19
# 16            nan           397.00               0.68                0.11
# 17         859.00           571.00               0.46                0.31
#
#     square_meter_price  weekday_exposition  month_exposition  year_exposition  \
# 0            120370.37                   3                 3             2019
# 2             92785.71                   3                 8             2015
# 3            408176.10                   4                 7             2015
# 4            100000.00                   1                 6             2018
# 7            110544.69                   3                 4             2019
# 9             88524.59                   6                 2             2017
# 10           127525.25                   3                11             2017
# 15           119230.77                   5                11             2017
# 16            81707.32                   3                11             2017
# 17           116111.11                   4                 9             2016
#
#    floor_category  floor_category_id  last_price_thousand
# 0     другой этаж                  2             13000.00
# 2     другой этаж                  2              5196.00
# 3     другой этаж                  2             64900.00
# 4     другой этаж                  2             10000.00
# 7     другой этаж                  2              7915.00
# 9     другой этаж                  2              5400.00
# 10    другой этаж                  2              5050.00
# 15    другой этаж                  2              4650.00
# 16    первый этаж                  1              6700.00
# 17    другой этаж                  2              4180.00

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Молодец, что сделала `copy`, тут можно `loc` не писать
# </div>

# %%
spb_data['center_km']=(spb_data['cityCenters_nearest'])/1000
spb_data['center_km']=round(spb_data['center_km'], 0).astype('int')
spb_data.head(10)
# Out:
#     total_images  last_price  total_area first_day_exposition  rooms  \
# 0             20 13000000.00      108.00           2019-03-07      3
# 2             10  5196000.00       56.00           2015-08-20      2
# 3              0 64900000.00      159.00           2015-07-24      3
# 4              2 10000000.00      100.00           2018-06-19      2
# 7              5  7915000.00       71.60           2019-04-18      2
# 9             18  5400000.00       61.00           2017-02-26      3
# 10             5  5050000.00       39.60           2017-11-16      1
# 15            16  4650000.00       39.00           2017-11-18      1
# 16            11  6700000.00       82.00           2017-11-23      3
# 17             6  4180000.00       36.00           2016-09-09      1
#
#     ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0             2.70            16        51.00      8         False   False
# 2             2.65             5        34.30      4         False   False
# 3             2.65            14        90.29      9         False   False
# 4             3.03            14        32.00     13         False   False
# 7             2.65            24        40.66     22         False   False
# 9             2.50             9        43.60      7         False   False
# 10            2.67            12        20.30      3         False   False
# 15            2.65            14        20.50      5         False   False
# 16            3.05             5        55.60      1         False   False
# 17            2.65            17        16.50      7         False   False
#
#     open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 0       False         25.00        0  Санкт-Петербург          18863.00
# 2       False          8.30        0  Санкт-Петербург          21741.00
# 3       False         27.41        0  Санкт-Петербург          28098.00
# 4       False         41.00        0  Санкт-Петербург          31856.00
# 7       False         18.90        2  Санкт-Петербург          23982.00
# 9       False          6.50        2  Санкт-Петербург          50898.00
# 10      False          8.50        0  Санкт-Петербург          38357.00
# 15      False          7.60        1  Санкт-Петербург          12900.00
# 16      False          9.00        0  Санкт-Петербург          22108.00
# 17      False         11.00        1  Санкт-Петербург          33564.00
#
#     cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 0              16028.00                 1         482.00                 2
# 2              13933.00                 1          90.00                 2
# 3               6800.00                 2          84.00                 3
# 4               8098.00                 2         112.00                 1
# 7              11634.00                 0            nan                 0
# 9              15008.00                 0            nan                 0
# 10             13878.00                 1         310.00                 2
# 15             14259.00                 1         590.00                 1
# 16             10698.00                 3         420.00                 0
# 17             14616.00                 0            nan                 1
#
#     ponds_nearest  days_exposition  living_area_ratio  kitchen_area_ratio  \
# 0          755.00              nan               0.47                0.23
# 2          574.00           558.00               0.61                0.15
# 3          234.00           424.00               0.57                0.17
# 4           48.00           121.00               0.32                0.41
# 7             nan              nan               0.57                0.26
# 9             nan           289.00               0.71                0.11
# 10         553.00           137.00               0.51                0.21
# 15         296.00            19.00               0.53                0.19
# 16            nan           397.00               0.68                0.11
# 17         859.00           571.00               0.46                0.31
#
#     square_meter_price  weekday_exposition  month_exposition  year_exposition  \
# 0            120370.37                   3                 3             2019
# 2             92785.71                   3                 8             2015
# 3            408176.10                   4                 7             2015
# 4            100000.00                   1                 6             2018
# 7            110544.69                   3                 4             2019
# 9             88524.59                   6                 2             2017
# 10           127525.25                   3                11             2017
# 15           119230.77                   5                11             2017
# 16            81707.32                   3                11             2017
# 17           116111.11                   4                 9             2016
#
#    floor_category  floor_category_id  last_price_thousand  center_km
# 0     другой этаж                  2             13000.00         16
# 2     другой этаж                  2              5196.00         14
# 3     другой этаж                  2             64900.00          7
# 4     другой этаж                  2             10000.00          8
# 7     другой этаж                  2              7915.00         12
# 9     другой этаж                  2              5400.00         15
# 10    другой этаж                  2              5050.00         14
# 15    другой этаж                  2              4650.00         14
# 16    первый этаж                  1              6700.00         11
# 17    другой этаж                  2              4180.00         15

# %% [markdown]
# Выясним, какая область входит в центр: посчитаем среднюю цену для каждого километра и построим график, показывающий, как цена зависит от удалённости от центра. Определим границу, где график сильно меняется — это и будет центральная зона.

# %%
spb_data_pivot_table=spb_data.pivot_table(index='center_km', values='square_meter_price', aggfunc='mean')
spb_data_pivot_table
# Out:
#            square_meter_price
# center_km
# 0                   245833.53
# 1                   176640.65
# 2                   157944.35
# 3                   121299.67
# 4                   133035.84
# 5                   140324.47
# 6                   151012.19
# 7                   156176.88
# 8                   124726.07
# 9                   113236.50
# 10                  112782.62
# 11                  108614.49
# 12                  109058.52
# 13                  108148.13
# 14                  104252.39
# 15                  104231.98
# 16                  100542.61
# 17                   96509.54
# 18                   96362.26
# 19                   98652.74
# 20                  103045.18
# 21                   94469.58
# 22                   91330.43
# 23                   91828.52
# 24                   84387.23
# 25                   91531.37
# 26                   89285.88
# 27                  132115.71
# 28                   81161.92
# 29                   72953.37
# 32                   64030.11
# 41                   96029.99

# %%
spb_data_pivot_table.plot()

# %% [markdown]
# После 7 км от центра города происходит резкое падение цены квадратного метра. Примем расстояние от центра города менее 7 км как центральную зону.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# 👍
# </div>

# %% [markdown]
# ### Квартиры в центре

# %% [markdown]
# Выделим сегмент квартир в центре.

# %%
spb_center_data=data.loc[data['cityCenters_nearest']<7000].copy()
spb_center_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3321 entries, 3 to 23694
# Data columns (total 31 columns):
# total_images            3321 non-null int64
# last_price              3321 non-null float64
# total_area              3321 non-null float64
# first_day_exposition    3321 non-null datetime64[ns]
# rooms                   3321 non-null int64
# ceiling_height          3321 non-null float64
# floors_total            3321 non-null int64
# living_area             3321 non-null float64
# floor                   3321 non-null int64
# is_apartment            3321 non-null bool
# studio                  3321 non-null bool
# open_plan               3321 non-null bool
# kitchen_area            3321 non-null float64
# balcony                 3321 non-null int64
# locality_name           3321 non-null object
# airports_nearest        3315 non-null float64
# cityCenters_nearest     3321 non-null float64
# parks_around3000        3321 non-null int64
# parks_nearest           2211 non-null float64
# ponds_around3000        3321 non-null int64
# ponds_nearest           2393 non-null float64
# days_exposition         2764 non-null float64
# living_area_ratio       3321 non-null float64
# kitchen_area_ratio      3321 non-null float64
# square_meter_price      3321 non-null float64
# weekday_exposition      3321 non-null int64
# month_exposition        3321 non-null int64
# year_exposition         3321 non-null int64
# floor_category          3321 non-null object
# floor_category_id       3321 non-null int64
# last_price_thousand     3321 non-null float64
# dtypes: bool(3), datetime64[ns](1), float64(14), int64(11), object(2)
# memory usage: 762.1+ KB

# %% [markdown]
# Проанализируем эту территорию и изучим следующие параметры: площадь, цена, число комнат, высота потолков.

# %%
spb_center_data['total_area'].describe()
# Out:
# count   3321.00
# mean      94.15
# std       60.10
# min       12.00
# 25%       57.80
# 50%       80.00
# 75%      110.60
# max      631.20
# Name: total_area, dtype: float64

# %% [markdown]
# Средняя общая площадь квартир в центре больше, чем по городу.

# %%
spb_center_data['square_meter_price'].describe()
# Out:
# count      3321.00
# mean     144616.77
# std       93706.74
# min       15345.27
# 25%       99411.76
# 50%      123333.33
# 75%      155882.35
# max     1907500.00
# Name: square_meter_price, dtype: float64

# %%
spb_center_data['last_price_thousand'].describe()
# Out:
# count     3321.00
# mean     14942.21
# std      24615.04
# min       1600.00
# 25%       6700.00
# 50%       9300.00
# 75%      14500.00
# max     763000.00
# Name: last_price_thousand, dtype: float64

# %% [markdown]
# Выше как средняя общая цена, так и цена квадратного метра.

# %%
spb_center_data['rooms'].describe()
# Out:
# count   3321.00
# mean       2.86
# std        1.47
# min        0.00
# 25%        2.00
# 50%        3.00
# 75%        4.00
# max       19.00
# Name: rooms, dtype: float64

# %%
spb_center_data['ceiling_height'].describe()
# Out:
# count   3321.00
# mean       2.97
# std        0.76
# min        2.40
# 25%        2.65
# 50%        2.84
# 75%        3.16
# max       32.00
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Комнат в среднем 3, а не 2. И средняя высота потолков выше.

# %% [markdown]
# Выделим факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления).

# %% [markdown]
# 1. Взаимосвязь числа комнат и цены квадратного метра.

# %%
spb_center_data['square_meter_price'].corr(spb_center_data['rooms'])
# Out:
# -0.0101478984722529

# %%
rooms_spb_center_pivot=spb_center_data.pivot_table(index='rooms', values='square_meter_price', aggfunc='mean')
rooms_spb_center_pivot.sort_values(by='rooms', ascending=True)
# Out:
#        square_meter_price
# rooms
# 0               146371.95
# 1               154864.10
# 2               142526.92
# 3               142801.16
# 4               137669.94
# 5               145011.14
# 6               153676.49
# 7               167223.47
# 8               192737.02
# 9               130529.17
# 10              104828.54
# 11              132639.74
# 14              116784.84
# 15              110169.49
# 16              105555.56
# 19               86091.83

# %%
rooms_spb_center_pivot.plot()

# %% [markdown]
# Судя по коэффициенту корреляции, связь отсутствует. Судя по графику, в среднем, самая большая цена за квадратный метр в центре - для 8-комнатных квартир, далее с увеличением числа комнат она снижается. Хотя этот "хвост" вообще неинформативен, т.к. квартир с количеством комнат более 8 - единицы.

# %%
rooms_spb_center_pivot=spb_center_data.pivot_table(index='rooms', values='square_meter_price', aggfunc='count')
rooms_spb_center_pivot.sort_values(by='rooms', ascending=True)
# Out:
#        square_meter_price
# rooms
# 0                      15
# 1                     478
# 2                     965
# 3                    1023
# 4                     470
# 5                     214
# 6                      81
# 7                      54
# 8                      10
# 9                       3
# 10                      2
# 11                      2
# 14                      1
# 15                      1
# 16                      1
# 19                      1

# %% [markdown]
# Если мы рассмотрим только число комнат от 0 до 8, то увидим, что наибольшая средняя цена квадратного метра у 3-комнатных квартир.

# %%
rooms_spb_center_pivot.query('rooms<=8').plot()

# %% [markdown]
# 2. Взаимосвязь удаленности от центра и цены квадратного метра.

# %%
spb_center_data['square_meter_price'].corr(spb_center_data['cityCenters_nearest'])
# Out:
# -0.02945913873382435

# %% [markdown]
# 3. Взаимосвязь года размещения объявления и цены квадратного метра.

# %%
year_spb_center_pivot=spb_center_data.pivot_table(index='year_exposition', values='square_meter_price', aggfunc='mean')
year_spb_center_pivot.sort_values(by='year_exposition', ascending=True)
# Out:
#                  square_meter_price
# year_exposition
# 2014                      195689.94
# 2015                      145884.42
# 2016                      138011.07
# 2017                      143165.40
# 2018                      141078.34
# 2019                      162670.70

# %%
year_spb_center_pivot.plot()

# %% [markdown]
# Общее падение цены за квадратный метр касается также и квартир в центре.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Ни один из параметров не оказывает ключевое влияние на цену квадратного метра. Наибольшее влияние у фактора общей цены: у тех квартир, что сами по себе дороже, выше и цена квадратного метра.

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Тут вопрос что считать ключевым влиянием, корреляция в 1 конечно не нашлась (если не считать очевидную зависимость цены от площади и цены за кв.м). Но в целом видно параметры, которые хоть чуть-чуть но влияют, как вариант можно было построить что-то такое:
# </div>

# %%
data.corrwith(data['last_price']).to_frame().style.background_gradient(cmap="coolwarm")
# Out:
# <style  type="text/css" >
#     #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow0_col0 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow2_col0 {
#             background-color:  #f7a889;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow3_col0 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow4_col0 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow5_col0 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow6_col0 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow7_col0 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow8_col0 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow9_col0 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow10_col0 {
#             background-color:  #6e90f2;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow11_col0 {
#             background-color:  #f1ccb8;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow12_col0 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow13_col0 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow14_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow15_col0 {
#             background-color:  #aac7fd;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow16_col0 {
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow17_col0 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow18_col0 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow19_col0 {
#             background-color:  #88abfd;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow20_col0 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow21_col0 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow22_col0 {
#             background-color:  #f08b6e;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow23_col0 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow24_col0 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow25_col0 {
#             background-color:  #6485ec;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow26_col0 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow27_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row0" class="row_heading level0 row0" >total_images</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow0_col0" class="data row0 col0" >0.104526</td>
#             </tr>
#             <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row1" class="row_heading level0 row1" >last_price</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow1_col0" class="data row1 col0" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row2" class="row_heading level0 row2" >total_area</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow2_col0" class="data row2 col0" >0.653795</td>
#             </tr>
#             <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row3" class="row_heading level0 row3" >rooms</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow3_col0" class="data row3 col0" >0.363389</td>
#             </tr>
#             <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row4" class="row_heading level0 row4" >ceiling_height</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow4_col0" class="data row4 col0" >0.0795959</td>
#             </tr>
#             <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row5" class="row_heading level0 row5" >floors_total</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow5_col0" class="data row5 col0" >-0.00692021</td>
#             </tr>
#             <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row6" class="row_heading level0 row6" >living_area</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow6_col0" class="data row6 col0" >0.585774</td>
#             </tr>
#             <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row7" class="row_heading level0 row7" >floor</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow7_col0" class="data row7 col0" >0.0266898</td>
#             </tr>
#             <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row8" class="row_heading level0 row8" >is_apartment</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow8_col0" class="data row8 col0" >0.0265098</td>
#             </tr>
#             <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row9" class="row_heading level0 row9" >studio</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow9_col0" class="data row9 col0" >-0.0253617</td>
#             </tr>
#             <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row10" class="row_heading level0 row10" >open_plan</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow10_col0" class="data row10 col0" >-0.0088019</td>
#             </tr>
#             <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row11" class="row_heading level0 row11" >kitchen_area</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow11_col0" class="data row11 col0" >0.513878</td>
#             </tr>
#             <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row12" class="row_heading level0 row12" >balcony</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow12_col0" class="data row12 col0" >0.00839709</td>
#             </tr>
#             <tr>
#                         <th id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7flevel0_row13" class="row_heading level0 row13" >airports_nearest</th>
#                         <td id="T_b6a0fe58_bbc1_11eb_a107_02420a391e7frow13_col0" class="data row13 col0" >-0.0262353</td>
#             </tr>

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарий ревьюера</h2>
#
# Тут например, с точки зрения корреляции растояние до центра не влияет, но с точки зрения здравого смысла и графиков видно что в центре жильё дороже. Ещё замена данных на медианы делает плохо для корреляции (высота потолков например), тут она практически нулевая, при этом если на медианы не заменять, то можешь посмотреть, что будет :)
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод info())
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  посчитано и добавлено в таблицу: цена квадратного метра
# - [x]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [x]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [x]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [x]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [x]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [x]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [x]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [x]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [x]  в каждом этапе есть выводы
# - [x]  есть общий вывод
